# %%
def get_roomtype():
    while True:
        try:
            room_type = int(input('Room type: '))
            if 1<=room_type<=3:
                break
            else:
                print('Wrong Room type, Please try again.')
        except:
            print('Wrong Room type, Please try again.')
    return room_type

# %%
print('WELCOME TO HOTEL BOOKINGS PLATFORM')
print('Types of available rooms: \n  (1) Room \n  (2) Studio \n  (3) One Bedroom Unit')

room_cost = {1:80,
            2:120,
            3:180}

room_cost_concession = {
    1:65,
    2:105,
    3:165
}

roomtype = {
    1:'Room',
    2: 'Studio',
    3: 'One Bedroom Unit'
}

while True:
    try:
        room_type = int(input('Room type: '))
        if 1<=room_type<=3:
            break
        else:
            print('Wrong Room type, Please try again.')
    except:
        print('Wrong Room type, Please try again.')
    
    
while True:
    try:
        no_of_guest = int(input('Number of guests: ')) 
        if no_of_guest>=1:
            break
        else:
            print('Wrong Number of guests:, Please try again.')
    except:
        print('Wrong Number of guests:, Please try again.')
        

while True:
    try:
        no_of_days = int(input('Number of Days: ')) 
        if no_of_days>=1:
            break
        else:
            print('Wrong Number of Days')
    except:
        print('Wrong Number of Days')

while True:
    try:
        no_of_concession = int(input('Number of concession tickets included (under 18, over 65 or student): '))
        if no_of_concession>=0:
            break
        else:
            print('Wrong input, pleae try again')
    except:
        print('Wrong input, pleae try again')
        
               
while True:
    try:
        special_view = input('Special view: ')
        if special_view=='Y':
            break
        else:
            print('Wrong input, Please try again.')
    except:
         print('Wrong input, Please try again.')


while True:
    try:
        free_cancelation = input('Free cancelation: ')
        if free_cancelation=='Y':
            break
        else:
            print('Wrong input, Please try again.')
    except:
         print('Wrong input, Please try again.')
            
while True:
    try:
        Breakfast = input('Breakfast: ')
        if Breakfast=='Y':
            break
        else:
            print('Wrong input, Please try again.')
    except:
         print('Wrong input, Please try again.')
            
while True:
    try:
        Membership = input('Member gold/silver/No (G/S/N): ')
        if Membership in ('G','S','N'):
            break
        else:
            print('Wrong input, Please try again.')
    except:
         print('Wrong input, Please try again.')

print()


print('--- {} chosen ---'.format(roomtype[room_type]))
    
print('--- You are booking for {} guests ---'.format(no_of_guest))
print('--- {} days chosen --'.format(no_of_days))
print('--- {} concessions chosen ---'.format(no_of_concession))

print('--- {} ---'.format('Free cancelation chosen' if free_cancelation=='Y' else 'Free cancelation not chosen'))
print('--- A room with {} chosen---'.format('Special view' if special_view=='Y' else 'Special view not'))
print('--- {} chosen---'.format('Breakfast' if Breakfast=='Y' else 'Breakfast not'))

member_ship = 'Gold' if Membership=='G' else ('Silver' if Membership=='S' else 'No')
print('--- {} Member discount applied---'.format(member_ship))
print('--- Bulk discount {} applied ---'.format("has" if no_of_days>=6 else "hasn't"))

cost_without_cons = (no_of_guest-no_of_concession)*no_of_days*room_cost[room_type]
cost_cons = no_of_concession*no_of_days*room_cost_concession[room_type]

Total_Cost = cost_without_cons + cost_cons
Additional_charge = (15 if special_view=='Y' else 0) + (3 if free_cancelation=='Y' else 0) + (3 if Breakfast=='Y' else 0)
Total_Cost = Total_Cost*(1+Additional_charge/100)

Discount = (10 if no_of_days>6 else 0) + (10 if Membership=='G' else (5 if Membership=='S' else 0))
total_discount = Total_Cost*Discount/100
print(Total_Cost-total_discount)
print(total_discount)
# Out:
# WELCOME TO HOTEL BOOKINGS PLATFORM
# Types of available rooms:
#   (1) Room
#   (2) Studio
#   (3) One Bedroom Unit
# Room type: qw
# Wrong Room type, Please try again.
# Room type: 123
# Wrong Room type, Please try again.
# Room type: 2
# Number of guests: wer
# Wrong Number of guests:, Please try again.
# Number of guests: 6
# Number of Days: e
# Wrong Number of Days
# Number of Days: 5
# Number of concession tickets included (under 18, over 65 or student): -1
# Wrong input, pleae try again
# Number of concession tickets included (under 18, over 65 or student): d
# Wrong input, pleae try again
# Number of concession tickets included (under 18, over 65 or student): 2
# Special view: dd
# Wrong input, Please try again.
# Special view: 3
# Wrong input, Please try again.
# Special view: Y
# Free cancelation: d
# Wrong input, Please try again.
# Free cancelation: Y
# Breakfast: 4e
# Wrong input, Please try again.
# Breakfast: Y
# Member gold/silver/No (G/S/N): f
# ...
