# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid_19_data.csv')

# %%
data = df.groupby(by=['Province/State']).sum()

# %%
data.reset_index(inplace=True)

# %%
data.columns = ['State','TotalCases','TotalDeaths','NewCases']

# %%
data = data.iloc[:50,:]

# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt
# read the dataset
data = pd.read_csv('US_Covid19_data.csv')
# consider only required columns
data = data[['State','TotalCases','NewCases','TotalDeaths',]]

# %%
# display the data
data
# Out:
#                            State  TotalCases  TotalDeaths   NewCases
# 0                   Montreal, QC          17            0          0
# 1             Norfolk County, MA           7            0          0
# 2                        Abruzzo     8917934       352332    6241816
# 3                           Acre    12728073       258081   10377709
# 4                Adygea Republic     2619614        25156    2257869
# 5                 Aguascalientes     4342961       363179     717440
# 6                          Aichi     4265311        75370    3744545
# 7                          Akita       44971          645      39147
# 8                        Alabama    91057235      1632369          0
# 9                        Alagoas    32254176       780708   30140107
# 10            Alameda County, CA           6            0          0
# 11                        Alaska     9950066        49472          0
# 12                       Alberta    23068952       293698   20288159
# ...

# %%
# set figure size
plt.figure(figsize=(20,5))

# plotting state vs TotalCases
plt.plot(data['State'],data['TotalCases'],color='r',label='TotalCases') 
# plotting state vs NewCases
plt.plot(data['State'],data['NewCases'],color='b',label='NewCases') 
# plotting state vs TotalDeaths
plt.plot(data['State'],data['TotalDeaths'],color='green',label='TotalDeaths') 
# set verticle x tick
plt.xticks(x, rotation='vertical')
plt.xlabel('State') # x label
plt.ylabel('Number in 10^8') # y label
plt.legend()
# show the plot
plt.show()

# %%
data=data.head()

# %%
import pandas as pd
df = pd.read_csv('test.csv')

# %%
df
# Out:
#         Province         Country  Confirmed  Deaths  Recovered
# 0          Anhui  Mainland China          1       0          0
# 1        Beijing  Mainland China         14       0          0
# 2      Chongqing  Mainland China          6       0          0
# 3         Fujian  Mainland China          1       0          0
# 4          Gansu  Mainland China          0       0          0
# 5      Guangdong  Mainland China         26       0          0
# 6        Guangxi  Mainland China          2       0          0
# 7        Guizhou  Mainland China          1       0          0
# 8         Hainan  Mainland China          4       0          0
# 9          Hebei  Mainland China          1       0          0
# 10  Heilongjiang  Mainland China          0       0          0
# 11         Henan  Mainland China          5       0          0

# %%
df.to_csv('newfile.csv')

# %%
# plot with x-tick 
import matplotlib.pyplot as plt
impact = ['Sleep', 'Rest', 'Excessive','Emotional Anxiety', 'Learning', 'Other']
Occurrences = [61.2,14.1,12.6,6.7,2.0,3.4] # contains all percentage
plt.figure(figsize=(10,4)) # setting figure size
# change the value of bins to see how its working
plt.hist(x=Occurrences, bins=200, color='blue',rwidth=0.85)
plt.xticks(Occurrences, impact,rotation='vertical') # to set the impact as x axis 
plt.xlabel('Impact %')
plt.ylabel('Occurrences')
plt.title('Histogram')
plt.show()

# %%
np.linspace(0, 60, 60)
# Out:
# array([ 0.        ,  1.01694915,  2.03389831,  3.05084746,  4.06779661,
#         5.08474576,  6.10169492,  7.11864407,  8.13559322,  9.15254237,
#        10.16949153, 11.18644068, 12.20338983, 13.22033898, 14.23728814,
#        15.25423729, 16.27118644, 17.28813559, 18.30508475, 19.3220339 ,
#        20.33898305, 21.3559322 , 22.37288136, 23.38983051, 24.40677966,
#        25.42372881, 26.44067797, 27.45762712, 28.47457627, 29.49152542,
#        30.50847458, 31.52542373, 32.54237288, 33.55932203, 34.57627119,
#        35.59322034, 36.61016949, 37.62711864, 38.6440678 , 39.66101695,
#        40.6779661 , 41.69491525, 42.71186441, 43.72881356, 44.74576271,
#        45.76271186, 46.77966102, 47.79661017, 48.81355932, 49.83050847,
#        50.84745763, 51.86440678, 52.88135593, 53.89830508, 54.91525424,
#        55.93220339, 56.94915254, 57.96610169, 58.98305085, 60.        ])

# %%
import numpy as np
