# %%
import nltk
nltk.download("punkt") #https://nios.ac.in/media/documents/srsec317newE/317EL12.pdf
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\avitr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words = nltk.word_tokenize(sentence)
new_words= [word for word in words if word.isalnum()]

# %%
new_words
# Out:
# ['MODULE',
#  '3',
#  'Notes',
#  '128',
#  'Political',
#  'Science',
#  'Structure',
#  'of',
#  'Government',
#  '12',
#  'SUPREME',
#  'COURT',
#  'OF',
#  'INDIA',
#  'he',
#  'Supreme',
#  'Court',
#  'is',
#  'the',
#  'highest',
#  'court',
#  'of',
#  'India',
#  'It',
#  'is',
#  'at',
#  'the',
#  'apex',
#  'of',
#  'the',
#  'Indian',
#  'judicial',
#  'system',
#  'In',
#  'the',
#  'previous',
#  'two',
#  'lessons',
#  'you',
#  'have',
#  'learnt',
#  'that',
#  'the',
#  'Union',
#  'legislature',
#  'which',
#  'is',
#  'known',
#  'as',
#  'Parliament',
#  'makes',
#  'laws',
#  'for',
#  'the',
#  'whole',
#  'country',
#  'in',
#  'respect',
#  'of',
#  'the',
#  'Union',
#  'and',
#  'the',
#  'Concurrent',
#  'Lists',
#  'and',
#  'the',
#  'executive',
#  'comprising',
#  'the',
#  'President',
#  'Council',
#  'of',
#  'Ministers',
#  'and',
#  'bureaucracy',
#  'enforces',
#  'them',
#  'Judiciary',
#  'the',
#  'third',
#  'organ',
#  'of',
#  'the',
# ...

# %%
import fitz #pymuPDF

# %%
file = fitz.open('317EL12.pdf')
list_file=[]
for i in file.pages():
    list_file.append(i.getText())

for j in range(file.pageCount):
    for i in ['\n','\xa0','\xad']:
        if i in list_file[j]:
            list_file[j]=list_file[j].replace(i,' ')
file.close()
file_str = ''
for i in list_file:
    file_str = file_str + i

# %%
sentence = file_str

# %%
sentence
# Out:
# 'MODULE - 3 Notes 128 Political Science Structure of Government 12 SUPREME COURT OF INDIA he Supreme Court is the highest court of India. It is at the apex of the Indian judicial system. In the previous two lessons, you have learnt that the Union legislature, which is known as Parliament, makes laws for the whole country in respect of the Union and the Concurrent Lists and the executive comprising the President, Council of Ministers and bureaucracy enforces them. Judiciary, the third organ of the government, has an equally important role to play. It settles the disputes, interprets laws, protects fundamental rights and acts as guardian of the Constitution. In this lesson, you will learn that India has a single unified and integrated judicial system and that the Supreme Court is the highest court in India. Objectives After studying this lesson, you will be able to � recognise that India has a single integrated and unified judicial system; � describe the composition and organization of
# ...

# %%
from nltk.corpus import stopwords

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
filtered_words = [w for w in new_words if not w in stopwords.words('english')]

# %%
len(new_words)
# Out:
# 3775

# %%
from collections import Counter

# %%
Counter(filtered_words)
# Out:
# Counter({'MODULE': 9,
#          '3': 11,
#          'Notes': 9,
#          '128': 1,
#          'Political': 5,
#          'Science': 5,
#          'Structure': 9,
#          'Government': 12,
#          '12': 1,
#          'SUPREME': 2,
#          'COURT': 2,
#          'OF': 2,
#          'INDIA': 2,
#          'Supreme': 102,
#          'Court': 138,
#          'highest': 5,
#          'court': 10,
#          'India': 30,
#          'It': 30,
#          'apex': 1,
#          'Indian': 4,
#          'judicial': 16,
#          'system': 7,
#          'In': 11,
#          'previous': 3,
#          'two': 10,
#          'lessons': 1,
#          'learnt': 1,
#          'Union': 2,
#          'legislature': 4,
#          'known': 1,
#          'Parliament': 7,
#          'makes': 1,
#          'laws': 2,
#          'whole': 2,
#          'country': 5,
#          'respect': 1,
#          'Concurrent': 1,
#          'Lists': 1,
#          'executive': 4,
#          'comprising': 1,
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
a=plt.imread('23.JPG')
plt.imshow(a)
plt.show()

# %%
from PIL import Image 
image_file = Image.open("23.JPG") # open colour image
image_file = image_file.convert('1') # convert image to black and white

# %%
plt.imshow(image_file)
plt.show()

# %%
pix_val = list(image_file.getdata())

# %%
pix_val.count(0)
# Out:
# 18276

# %%
pix_val.count(255)
# Out:
# 91260

# %%
width, height = image_file.size

# %%
area = height*width
print(area)
# Out:
# 109536

# %%
percent = (pix_val.count(0)*100)/(pix_val.count(0) + pix_val.count(255))

# %%
area*percent/100
# Out:
# 18276.0
