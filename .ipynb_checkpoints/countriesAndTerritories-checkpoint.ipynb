# %%
# import the library 
import pandas as pd

# load the dummy Dataset
df_covid19 = pd.read_excel('COVID-19-geographic-disbtribution-worldwide-2020-08-20.xlsx')

# %%
df_covid19 # display the dataset
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-08-20   20      8  2020    160       8             Afghanistan
# 1     2020-08-19   19      8  2020      0       0             Afghanistan
# 2     2020-08-18   18      8  2020      3       0             Afghanistan
# 3     2020-08-17   17      8  2020     45       5             Afghanistan
# 4     2020-08-16   16      8  2020    120       7             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 37442 2020-03-25   25      3  2020      0       0                Zimbabwe
# 37443 2020-03-24   24      3  2020      0       1                Zimbabwe
# 37444 2020-03-23   23      3  2020      0       0                Zimbabwe
# 37445 2020-03-22   22      3  2020      1       0                Zimbabwe
# 37446 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
# groupby the dataset with countriesAndTerritories
# and get the sum of individual cases and deaths for each countries.

df_covid19.groupby("countriesAndTerritories")[['countriesAndTerritories','cases','deaths']].sum()
# Out:
#                          cases  deaths
# countriesAndTerritories
# Afghanistan              37759    1383
# Albania                   7812     234
# Algeria                  39847    1402
# Andorra                   1024      53
# Angola                    1966      90
# ...                        ...     ...
# Vietnam                    994      25
# Western_Sahara             766       1
# Yemen                     1893     539
# Zambia                   10218     269
# Zimbabwe                  5643     150
#
# [210 rows x 2 columns]

# %%
apply(lambda x: x.sort_values(ascending=False).head(3))

# %%
df_covid19.groupby("countriesAndTerritories")[['countriesAndTerritories','cases','deaths']].sum().sort_values(by=['cases'],ascending=False)
# Out:
#                                      cases  deaths
# countriesAndTerritories
# United_States_of_America           5529842  173177
# Brazil                             3456652  111100
# India                              2836925   53866
# Russia                              937321   15989
# South_Africa                        596060   12423
# ...                                    ...     ...
# Bonaire, Saint Eustatius and Saba       13       0
# Falkland_Islands_(Malvinas)             13       0
# Holy_See                                12       0
# British_Virgin_Islands                  11       1
# Anguilla                                 3       0
#
# [210 rows x 2 columns]

# %%
df_covid19[df_covid19['countriesAndTerritories']=='India']
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 16189 2020-08-20   20      8  2020  69652     977                   India
# 16190 2020-08-19   19      8  2020  64531    1092                   India
# 16191 2020-08-18   18      8  2020  55079     876                   India
# 16192 2020-08-17   17      8  2020  57981     941                   India
# 16193 2020-08-16   16      8  2020  63490     944                   India
# ...          ...  ...    ...   ...    ...     ...                     ...
# 16417 2020-01-04    4      1  2020      0       0                   India
# 16418 2020-01-03    3      1  2020      0       0                   India
# 16419 2020-01-02    2      1  2020      0       0                   India
# 16420 2020-01-01    1      1  2020      0       0                   India
# 16421 2019-12-31   31     12  2019      0       0                   India
#
#       geoId countryterritoryCode   popData2019 continentExp  \
# ...

# %%
df_covid19.groupby("countriesAndTerritories")[['countriesAndTerritories','cases','deaths']].sum().sort_values(by=['cases'],ascending=False)
# Out:
#                                      cases  deaths
# countriesAndTerritories
# United_States_of_America           5529842  173177
# Brazil                             3456652  111100
# India                              2836925   53866
# Russia                              937321   15989
# South_Africa                        596060   12423
# ...                                    ...     ...
# Bonaire, Saint Eustatius and Saba       13       0
# Falkland_Islands_(Malvinas)             13       0
# Holy_See                                12       0
# British_Virgin_Islands                  11       1
# Anguilla                                 3       0
#
# [210 rows x 2 columns]
