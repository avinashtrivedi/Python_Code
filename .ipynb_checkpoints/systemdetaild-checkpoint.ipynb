# %%
import subprocess

# %%
command = "pwd"

# %%
subprocess.check_output(command, shell=True).strip()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-5e6f096d1f3f> in <module>
# ----> 1 subprocess.check_output(command, shell=True).strip()
#
# ~\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409         kwargs['input'] = '' if kwargs.get('universal_newlines', False) else b''
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#     413
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         retcode = process.poll()
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#     514     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'pwd' returned non-zero exit status 1.

# %%
# import library
import subprocess
import re
import pwd
import grp
import socket

# open a txt file to write the data
fname = open("systeminfo.txt", "w")

# get the machine name 
mname = socket.gethostname()
fname.write(f"Machine Name: {mname}\n")

# user and group it is associated with
fname.write("users and their associated group: \n")
fname.write("\n") 
fname.write(60*"-")  # write '-' 60 times
fname.write("\n")
fname.write(f"{'User'.ljust(30)} {'Group'.ljust(30)}\n")
# go through all the users pwd.getpwall() 
# and write user and the group to the file one by one
for p in pwd.getpwall():        
    fname.write(f"{p[0].ljust(30)},{grp.getgrgid(p[3])[0].ljust(30)}\n")
fname.write(60*"-") 
fname.write("\n")
# processor information
# linux command to return processor information
command = "cat /proc/cpuinfo"      
# execute that command using python and store the result
processor_info = subprocess.check_output(command, shell=True).strip()
processor_info = processor_info.decode('UTF-8')
processor_info = processor_info.split("\n")
fname.write("\n") 
# write processor information to the file
for p in processor_info:
    if "processor" in p:
        fname.write("\n") 
        fname.write(f'Processor:{re.sub( ".*processor.*:", "", p,1)}\n')      # processor
    if "vendor_id" in p:
        fname.write(f'Vendor id:{re.sub( ".*vendor_id.*:", "", p,1)}\n')      # vendor id
    if "model" in p:
        fname.write(f'Model:{re.sub( ".*model.*:", "", p,1)}\n')              # model
    if "model name" in p:
        fname.write(f'Model name:{re.sub( ".*model name.*:", "", p,1)}\n')    # model name
    if "cache size" in p:
        fname.write(f'cache size:{re.sub( ".*model name.*:", "", p,1)}\n')    # cache
    
fname.write(60*"-") 
fname.write("\n")
# All services and current status

# linux command to list all service and their current status
command = "systemctl list-unit-files"  

# execute that command using python and store the result
services_info = subprocess.check_output(command, shell=True).strip()     
services_info = services_info.decode('UTF-8')
fname.write("\n")
# write all service and current status to the file
fname.write(services_info)   
# close the file
fname.close()                      
print("File systeminfo.txt has been created in current directory containing all the necessary details")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-e1193873f090> in <module>
#       1 # importing necessary files to complete this program
# ----> 2 import pwd, grp, subprocess, re, socket
#       3
#       4 # opening a file in write mode where the data will be written
#       5 f = open("info.txt", "w")
#
# ModuleNotFoundError: No module named 'pwd'

# %%
import pandas as pd

# %%
pd.read_csv('https://data.cityofchicago.org/resource/85ca-t3if.csv')
# Out:
#                                        crash_record_id  rd_no  \
# 0    7cbce32cb98ea0c8533e1114c22171f8314e5f0c954904...    NaN
# 1    22671faafc60e1ebd94f0986b0e070f2e7bf523da318f4...    NaN
# 2    5c342af98ba22deb2e2beea622e5c2277448f0c0488dd8...    NaN
# 3    6ee6d70dc4891ad56b5fa4693989563862dc855eef3d41...    NaN
# 4    80029ced235f4cf18833ced1de123100a22109eed40884...    NaN
# ..                                                 ...    ...
# 995  c68e0ba473cae08cf7eec7f6277bf58df5d9837e6f146d...    NaN
# 996  ce291b2c772c36ad231945fe2abb56824c7a73567b8419...    NaN
# 997  dc71fb106b90bdee1ce6833ac14166e4a0eb7bd27805b5...    NaN
# 998  b9c81b63c5bbc2e752db8b5789d76e31208feeb58a61c4...    NaN
# 999  710faf2e9095758e476d604cc854d9ec135dfdf27df854...    NaN
#
#     crash_date_est_i               crash_date  posted_speed_limit  \
# 0                NaN  2021-05-25T01:03:00.000                  30
# 1                NaN  2021-05-25T00:45:00.000                  30
# 2                NaN  2021-05-25T00:02:00.000                  30
# 3                NaN  2021-05-24T23:50:00.000                  30
# 4                NaN  2021-05-24T23:20:00.000                  30
# ..               ...                      ...                 ...
# 995              NaN  2021-05-21T13:00:00.000                  30
# 996              NaN  2021-05-21T13:00:00.000                  30
# 997              NaN  2021-05-21T12:59:00.000                  30
# 998              NaN  2021-05-21T12:55:00.000                  30
# 999              NaN  2021-05-21T12:53:00.000                  30
#
#     traffic_control_device      device_condition weather_condition  \
# 0              NO CONTROLS               UNKNOWN             CLEAR
# 1              NO CONTROLS           NO CONTROLS             CLEAR
# 2              NO CONTROLS           NO CONTROLS             CLEAR
# 3           TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 4           TRAFFIC SIGNAL           NO CONTROLS             CLEAR
# ..                     ...                   ...               ...
# 995         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 996            NO CONTROLS           NO CONTROLS             CLEAR
# 997            NO CONTROLS           NO CONTROLS             CLEAR
# 998            NO CONTROLS           NO CONTROLS             CLEAR
# 999         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#          lighting_condition          first_crash_type  ...  \
# 0    DARKNESS, LIGHTED ROAD                     ANGLE  ...
# 1    DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION  ...
# 2    DARKNESS, LIGHTED ROAD                  REAR END  ...
# 3    DARKNESS, LIGHTED ROAD                     ANGLE  ...
# 4                  DAYLIGHT  SIDESWIPE SAME DIRECTION  ...
# ..                      ...                       ...  ...
# 995                DAYLIGHT                PEDESTRIAN  ...
# 996                DAYLIGHT                     ANGLE  ...
# 997                DAYLIGHT                   TURNING  ...
# 998                DAYLIGHT              FIXED OBJECT  ...
# 999                DAYLIGHT                     ANGLE  ...
#
#     injuries_non_incapacitating  injuries_reported_not_evident  \
# 0                             0                              0
# 1                             0                              0
# 2                             0                              0
# 3                             1                              0
# 4                             0                              0
# ..                          ...                            ...
# 995                           1                              0
# 996                           0                              0
# 997                           0                              0
# 998                           2                              0
# 999                           0                              0
#
#     injuries_no_indication injuries_unknown crash_hour crash_day_of_week  \
# 0                        2                0          1                 3
# 1                        2                0          0                 3
# 2                        2                0          0                 3
# 3                        6                0         23                 2
# 4                        2                0         23                 2
# ..                     ...              ...        ...               ...
# 995                      1                0         13                 6
# 996                      2                0         13                 6
# 997                      2                0         12                 6
# 998                      0                0         12                 6
# 999                      2                0         12                 6
#
#     crash_month   latitude  longitude  \
# 0             5  41.884721 -87.710705
# 1             5  41.810637 -87.601869
# 2             5  41.808587 -87.678262
# 3             5  41.772081 -87.664079
# 4             5  41.892475 -87.635847
# ..          ...        ...        ...
# 995           5  41.992935 -87.711410
# 996           5  42.007995 -87.667174
# 997           5  41.882437 -87.670699
# 998           5  41.822794 -87.684088
# 999           5  41.852358 -87.670891
#
#                                      location
# 0    POINT (-87.710705020291 41.884721228247)
# 1    POINT (-87.601868847824 41.810637389919)
# 2    POINT (-87.678261940979 41.808586954402)
# 3    POINT (-87.664079498412 41.772081273834)
# 4    POINT (-87.635846695712 41.892475198776)
# ..                                        ...
# 995  POINT (-87.711409569719 41.992935022427)
# 996  POINT (-87.667174146719 42.007994919933)
# 997  POINT (-87.670698543087 41.882437378742)
# 998  POINT (-87.684088023354 41.822794015287)
# 999  POINT (-87.670891199234 41.852358394789)
#
# [1000 rows x 49 columns]
