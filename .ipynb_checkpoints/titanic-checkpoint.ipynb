# %% [markdown]
# # 1. Quesion

# %%
s="people can't achieve" # or "Strings are awesome!"
# Length should be 20
print("Length of s = %d" % len(s))
# First occurrence of "a" should be at index 8
print("The first occurrence of the letter a = %d" % s.index("a"))
# Number of a's should be 2

print("a occurs %d times" % s.count("a"))
# Slicing the string into bits

print("The first five characters are '%s'" % s[:5]) # Start to 5

print("The next five characters are '%s'" % s[5:10]) # 5 to 10

print("The thirteenth character is '%s'" % s[12]) # Just number 12

print("The characters with odd index are '%s'" %s[1::2]) #(0-based indexing)

print("The last five characters are '%s'" % s[-5:]) # 5th-from-last to end
# Convert everything to uppercase

print("String in uppercase: %s" % s.upper())

# Convert everything to lowercase

print("String in lowercase: %s" % s.lower())

# Check how a string starts

if s.startswith("Str"):

    print("String starts with 'Str'. Good!")

# Check how a string ends

if s.endswith("ome!"):

    print("String ends with 'ome!'. Good!")

# Split the string into three separate strings,

# each containing only a word

print("Split the words of the string: %s" % s.split(" "))
# Out:
# Length of s = 20
# The first occurrence of the letter a = 8
# a occurs 2 times
# The first five characters are 'peopl'
# The next five characters are 'e can'
# The thirteenth character is ' '
# The characters with odd index are 'epecntahee'
# The last five characters are 'hieve'
# String in uppercase: PEOPLE CAN'T ACHIEVE
# String in lowercase: people can't achieve
# Split the words of the string: ['people', "can't", 'achieve']

# %% [markdown]
# # 2. Question

# %%
# import the library
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read the dataset
dataset  = pd.read_csv('Titanic.csv')

# %%
dataset # display the content of dataset
# Out:
#           last                                       first gender   age  \
# 0       Braund                             Mr. Owen Harris      M  22.0
# 1      Cumings  Mrs. John Bradley (Florence Briggs Thayer)      F  38.0
# 2    Heikkinen                                  Miss Laina      F  26.0
# 3     Futrelle          Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 4        Allen                           Mr. William Henry      M  35.0
# ..         ...                                         ...    ...   ...
# 886   Montvila                                 Rev. Juozas      M  27.0
# 887     Graham                         Miss Margaret Edith      F  19.0
# 888   Johnston               Miss Catherine Helen "Carrie"      F   NaN
# 889       Behr                             Mr. Karl Howell      M  26.0
# 890     Dooley                                 Mr. Patrick      M  32.0
#
#      class     fare     embarked survived
# 0        3   7.2500  Southampton       no
# ...

# %%
# survivor and non survivor dataframe
survivors = dataset[dataset['survived']=='yes']
non_survivors = dataset[dataset['survived']=='no']

# compute gender wise survivor and non_survivor status
survivors_genderwise = survivors.groupby(['gender']).size().values
non_survivors_genderwise = non_survivors.groupby(['gender']).size().values

# graph plotting
gender_categories = ['Female', 'Male']
plt.figure(figsize=(4,5))
plt.bar(range(len(survivors_genderwise)), survivors_genderwise, label='Survivors',color='g')
plt.bar(range(len(non_survivors_genderwise)), non_survivors_genderwise, bottom=survivors_genderwise, label='Non Survivors', color='r')
plt.xticks([0, 1.0], gender_categories )
plt.ylabel("Count")
plt.title("Survivors count by gender",fontsize=12)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 3. Question

# %%
name_list = ['Braund',
             'Cumings',
             'Heikkinen',
             'Futrelle',
             'Allen',
             'Moran',
             'McCarthy',
             'Palsson',
             'Johnson',
             'Nasser']

# %%
def read_first3(name_list):
    for i in name_list:
        print('First 3 letters of the name ',i,' is: ',i[:3])

# %%
read_first3(name_list)
# Out:
# First 3 letters of the name  Braund  is:  Bra
# First 3 letters of the name  Cumings  is:  Cum
# First 3 letters of the name  Heikkinen  is:  Hei
# First 3 letters of the name  Futrelle  is:  Fut
# First 3 letters of the name  Allen  is:  All
# First 3 letters of the name  Moran  is:  Mor
# First 3 letters of the name  McCarthy  is:  McC
# First 3 letters of the name  Palsson  is:  Pal
# First 3 letters of the name  Johnson  is:  Joh
# First 3 letters of the name  Nasser  is:  Nas

# %% [markdown]
# # 4. Question

# %%
# read the dataset
data = pd.read_csv('Titanic.csv')

# %% [markdown]
# # a. Printout the first 15 and the last 5 records in the dataset.

# %%
# first 15 records
data.head(15)
# Out:
#            last                                       first gender   age  \
# 0        Braund                             Mr. Owen Harris      M  22.0
# 1       Cumings  Mrs. John Bradley (Florence Briggs Thayer)      F  38.0
# 2     Heikkinen                                  Miss Laina      F  26.0
# 3      Futrelle          Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 4         Allen                           Mr. William Henry      M  35.0
# 5         Moran                                   Mr. James      M   NaN
# 6      McCarthy                               Mr. Timothy J      M  54.0
# 7       Palsson                        Master Gosta Leonard      M   2.0
# 8       Johnson    Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 9        Nasser                 Mrs. Nicholas (Adele Achem)      F  14.0
# 10    Sandstrom                         Miss Marguerite Rut      F   4.0
# 11      Bonnell                              Miss Elizabeth      F  58.0
# ...

# %%
# last 5 records
data.tail(5)
# Out:
#          last                           first gender   age  class   fare  \
# 886  Montvila                     Rev. Juozas      M  27.0      2  13.00
# 887    Graham             Miss Margaret Edith      F  19.0      1  30.00
# 888  Johnston   Miss Catherine Helen "Carrie"      F   NaN      3  23.45
# 889      Behr                 Mr. Karl Howell      M  26.0      1  30.00
# 890    Dooley                     Mr. Patrick      M  32.0      3   7.75
#
#         embarked survived
# 886  Southampton       no
# 887  Southampton      yes
# 888  Southampton       no
# 889    Cherbourg      yes
# 890   Queenstown       no

# %% [markdown]
# # b. What is the shape of the dataset and how many columns does the dataset have?

# %%
# shape
data.shape
# Out:
# (891, 8)

# %%
# number of columns
data.shape[1]
# Out:
# 8

# %% [markdown]
# # c. Identify what columns have null values

# %%
data.isna().sum()!=0
# Out:
# last        False
# first       False
# gender      False
# age          True
# class       False
# fare        False
# embarked    False
# survived    False
# dtype: bool

# %%
# here age column have null value

# %%
data.columns[list(data.isna().sum()!=0).index(True)]
# Out:
# 'age'

# %% [markdown]
# # d. Clean the dataset, remove duplicate entries if there are.

# %%
# initial shape
data.shape
# Out:
# (891, 8)

# %%
# remove duplicate rows if available
data.drop_duplicates(keep=False,inplace=True)

# %%
# final shape
data.shape
# Out:
# (891, 8)

# %%
# As,initial and final shape is same ,it means there is no duplicate

# %% [markdown]
# # e. Printout the top 5 embarkation of passengers

# %%
# just to check how many unique values in 'embarked' column with their counts.
data['embarked'].value_counts()
# Out:
# Southampton    646
# Cherbourg      168
# Queenstown      77
# Name: embarked, dtype: int64

# %%
data['embarked'].head(5)
# Out:
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# Name: embarked, dtype: object

# %% [markdown]
# # f.  How many are males whose age is greater 35 who survived the titanic accident?

# %%
df = data[(data['gender']=='M') & (data['age']>35) & (data['survived']=='yes')]
df
# Out:
#                  last                                  first gender   age  \
# 187           Romaine   Mr. Charles Hallace ("Mr C Rolmane")      M  45.0
# 209             Blank                              Mr. Henry      M  40.0
# 224              Hoyt                 Mr. Frederick Maxfield      M  38.0
# 248          Beckwith                    Mr. Richard Leonard      M  37.0
# 288            Hosono                           Mr. Masabumi      M  42.0
# 338              Dahl                        Mr. Karl Edwart      M  45.0
# 390            Carter                     Mr. William Ernest      M  36.0
# 400          Niskanen                               Mr. Juha      M  39.0
# 414           Sundman                       Mr. Johan Julian      M  44.0
# 449           Peuchen                  Major. Arthur Godfrey      M  52.0
# 453        Goldenberg                           Mr. Samuel L      M  49.0
# 460          Anderson                              Mr. Harry      M  48.0
# ...

# %%
# number of males whose age is greater 35 who survived the titanic accident.
len(df)
# Out:
# 26

# %% [markdown]
# # g. What is the average fare of female passengers?

# %%
data.columns
# Out:
# Index(['last', 'first', 'gender', 'age', 'class', 'fare', 'embarked',
#        'survived'],
#       dtype='object')

# %%
df_female = data[data['gender']=='F']
df_female
# Out:
#           last                                       first gender   age  \
# 1      Cumings  Mrs. John Bradley (Florence Briggs Thayer)      F  38.0
# 2    Heikkinen                                  Miss Laina      F  26.0
# 3     Futrelle          Mrs. Jacques Heath (Lily May Peel)      F  35.0
# 8      Johnson    Mrs. Oscar W (Elisabeth Vilhelmina Berg)      F  27.0
# 9       Nasser                 Mrs. Nicholas (Adele Achem)      F  14.0
# ..         ...                                         ...    ...   ...
# 880    Shelley         Mrs. William (Imanita Parrish Hall)      F  25.0
# 882   Dahlberg                           Miss Gerda Ulrika      F  22.0
# 885       Rice              Mrs. William (Margaret Norton)      F  39.0
# 887     Graham                         Miss Margaret Edith      F  19.0
# 888   Johnston               Miss Catherine Helen "Carrie"      F   NaN
#
#      class     fare     embarked survived
# 1        1  71.2833    Cherbourg      yes
# ...

# %%
# average fare for female passengers
df_female['fare'].mean()
# Out:
# 44.47981783439487

# %% [markdown]
# # h. Is there a relationship between age and class who survived the accident?

# %%
# dataframe containing age and class of passengers who survived the accident?
df_age_class_rel = data[data['survived']=='yes'][['age','class']]
df_age_class_rel
# Out:
#       age  class
# 1    38.0      1
# 2    26.0      3
# 3    35.0      1
# 8    27.0      3
# 9    14.0      2
# ..    ...    ...
# 875  15.0      3
# 879  56.0      1
# 880  25.0      2
# 887  19.0      1
# 889  26.0      1
#
# [342 rows x 2 columns]

# %%
# compute a correlation  between age and class
# its value can be in the range -1 to 1
# 1 indicates perfect positive relation
# -1 indicates perfect negative relation
# 0 means no relation.
#  ± 0.30 to ± 0.49 : medium relation
# source : https://www.statisticssolutions.com/pearsons-correlation-coefficient/

df_age_class_rel['age'].corr(df_age_class_rel['class'])
# Out:
# -0.41807330301063617

# %%
# Hence age and class is having a medium relation.
