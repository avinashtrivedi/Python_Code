# %% [markdown]
# # Generic Program

# %%
global_var = 'global'
def sub1():
    sub1var = 'sub1'
    print()
    print('sub 1 function')
    print('global variable:',global_var)
    print('Local variable 1:',sub1var)
    def sub2():
        sub2var = 'sub2'
        print()
        print('sub 2 function')
        print('global variable:',global_var)
        print('Local variable 1:',sub1var)
        print('Local variable 2:',sub2var)
        def sub3():
            sub3var = 'sub3'
            print()
            print('sub 3 function')
            print('global variable:',global_var)
            print('Local variable 1:',sub1var)
            print('Local variable 2:',sub2var)
            print('Local variable 3:',sub3var)
            def sub4():
                sub4var = 'sub4'
                print()
                print('sub 4 function')
                print('global variable:',global_var)
                print('Local variable 3:',sub1var)
                print('Local variable 2:',sub2var)
                print('Local variable 3:',sub3var)
                print('Local variable 4:',sub4var)
                def sub5():
                    sub5var = 'sub5'
                    print()
                    print('sub 5 function')
                    print('global variable:',global_var)
                    print('Local variable 1:',sub1var)
                    print('Local variable 2:',sub2var)
                    print('Local variable 3:',sub3var)
                    print('Local variable 4:',sub4var)
                    print('Local variable 5:',sub5var)
                    def sub6():
                        sub6var = 'sub6'
                        print()
                        print('sub 6 function')
                        print('global variable:',global_var)
                        print('Local variable 1:',sub1var)
                        print('Local variable 2:',sub2var)
                        print('Local variable 3:',sub3var)
                        print('Local variable 4:',sub4var)
                        print('Local variable 5:',sub5var)
                        print('Local variable 6:',sub6var)
# maintain proper indentation to call the subprograms  
                    sub6()    
                sub5()
            sub4()
        sub3()
    sub2()
sub1()
# Out:
# sub 1 function
# global variable: global
# Local variable 1: sub1
#
# sub 2 function
# global variable: global
# Local variable 1: sub1
# Local variable 2: sub2
#
# sub 3 function
# global variable: global
# Local variable 1: sub1
# Local variable 2: sub2
# Local variable 3: sub3
#
# sub 4 function
# global variable: global
# Local variable 3: sub1
# Local variable 2: sub2
# Local variable 3: sub3
# Local variable 4: sub4
#
# sub 5 function
# global variable: global
# Local variable 1: sub1
# Local variable 2: sub2
# Local variable 3: sub3
# Local variable 4: sub4
# Local variable 5: sub5
#
# sub 6 function
# global variable: global
# Local variable 1: sub1
# Local variable 2: sub2
# Local variable 3: sub3
# Local variable 4: sub4
# Local variable 5: sub5
# Local variable 6: sub6

# %% [markdown]
# # Question

# %%
x=1
y=3
z=5
def sub1(): 
    a = 7
    y = 9
    z = 11
    print('a: ',a)
    print('y: ',y)
    print('z: ',z)
    def sub2():
        global x
        a = 13
        x = 15
        w = 17
        print('a: ',a)
        print('x: ',x)
        print('w: ',w)
        def sub3(): 
            nonlocal a
            a = 19
            b = 21
            z = 23
            print('a: ',a)
            print('b: ',b)
            print('z: ',z)
            def sub4():
                global x
                a = 25
                x = 27
                print('a: ',a)
                print('x: ',x)
                def sub5():
                    nonlocal a
                    a = 29
                    z = 31
                    print('a: ',a)
                    print('z: ',z)
                    def sub6():
                        global y
                        a = 33
                        y = 35
                        v = 37
                        print('a: ',a)
                        print('y: ',y)
                        print('v: ',v)
# maintain proper indentation to call the subprograms  
                    sub6()    
                sub5()
            sub4()
        sub3()
    sub2()
sub1()
# Out:
# a:  7
# y:  9
# z:  11
# a:  13
# x:  15
# w:  17
# a:  19
# b:  21
# z:  23
# a:  25
# x:  27
# a:  29
# z:  31
# a:  33
# y:  35
# v:  37
