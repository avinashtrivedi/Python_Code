# %% [markdown]
# # Load the dataset

# %%
import pandas as pd
dataCleansing_DF = pd.read_csv('K303_DataPreparation_ClassExample.csv')
dataCleansing_DF
# Out:
#       Customer           SSN                   Name   Birthdate  Current age  \
# 0          1.0   539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 1          2.0   444-05-4079          victor, BRETT    1|1|1932          NaN
# 2          3.0   418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 3          4.0    065-633311          Foster, Chris    2|8|1947          NaN
# 4          5.0   059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...        ...           ...                    ...         ...          ...
# 1495       NaN   004-10-8303           Rice, Joshua  19|10|1976          NaN
# 1496       NaN   510-02-4583        Woodard, Brenna   23|5|1938          NaN
# 1497       NaN   074-07-5294           Bryan, Talon   21|2|1944          NaN
# 1498       NaN   287-80-0088           Grady Foster  13|11|1935          NaN
# 1499       NaN   803-48-4970         Kirkland, Joan  24|11|1964          NaN
#
# ...

# %% [markdown]
# # customer column

# %%
# remove rows with blanks
dataCleansing_DF.dropna(subset=['Customer'], inplace=True)
dataCleansing_DF
# Out:
#       Customer           SSN                   Name   Birthdate  Current age  \
# 0          1.0   539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 1          2.0   444-05-4079          victor, BRETT    1|1|1932          NaN
# 2          3.0   418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 3          4.0    065-633311          Foster, Chris    2|8|1947          NaN
# 4          5.0   059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...        ...           ...                    ...         ...          ...
# 1489    1500.0   366-03-5021        Declan Santiago   23|9|1934          NaN
# 1490    9999.0   071-92-1603       Abigail Figueroa    2|7|1939          NaN
# 1491    9999.0   901-05-8142           Neal, Rashad   10|6|1935          NaN
# 1492    9999.0   133-99-5496             Tyson, Eve   13|5|2028          NaN
# 1493    9999.0   776-25-5466           Nieves, Thor   7|11|1951          NaN
#
# ...

# %%
# remove rows with 9999
dataCleansing_DF.drop(dataCleansing_DF[dataCleansing_DF.Customer==9999].index,inplace=True)
dataCleansing_DF
# Out:
#       Customer           SSN                   Name   Birthdate  Current age  \
# 0          1.0   539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 1          2.0   444-05-4079          victor, BRETT    1|1|1932          NaN
# 2          3.0   418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 3          4.0    065-633311          Foster, Chris    2|8|1947          NaN
# 4          5.0   059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...        ...           ...                    ...         ...          ...
# 1485    1496.0   347-70-0762        Hancock, Quincy   28|9|1965          NaN
# 1486    1497.0    63819-2849         Gibson, Ifeoma   31|7|1930          NaN
# 1487    1498.0   670-57-4549          Hawkins, Macy   21|7|1954          NaN
# 1488    1499.0   166-84-2698           Reese Butler  30|10|1966          NaN
# 1489    1500.0   366-03-5021        Declan Santiago   23|9|1934          NaN
#
# ...

# %%
# remove duplicates
dataCleansing_DF.drop_duplicates(subset=['Customer'],inplace=True)
dataCleansing_DF
# Out:
#       Customer           SSN                   Name   Birthdate  Current age  \
# 0          1.0   539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 1          2.0   444-05-4079          victor, BRETT    1|1|1932          NaN
# 2          3.0   418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 3          4.0    065-633311          Foster, Chris    2|8|1947          NaN
# 4          5.0   059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...        ...           ...                    ...         ...          ...
# 1485    1496.0   347-70-0762        Hancock, Quincy   28|9|1965          NaN
# 1486    1497.0    63819-2849         Gibson, Ifeoma   31|7|1930          NaN
# 1487    1498.0   670-57-4549          Hawkins, Macy   21|7|1954          NaN
# 1488    1499.0   166-84-2698           Reese Butler  30|10|1966          NaN
# 1489    1500.0   366-03-5021        Declan Santiago   23|9|1934          NaN
#
# ...

# %%
# Make 'customer' as row index
dataCleansing_DF.set_index('Customer', inplace=True)
dataCleansing_DF
# Out:
#                    SSN                   Name   Birthdate  Current age  \
# Customer
# 1.0        539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 2.0        444-05-4079          victor, BRETT    1|1|1932          NaN
# 3.0        418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 4.0         065-633311          Foster, Chris    2|8|1947          NaN
# 5.0        059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...                ...                    ...         ...          ...
# 1496.0     347-70-0762        Hancock, Quincy   28|9|1965          NaN
# 1497.0      63819-2849         Gibson, Ifeoma   31|7|1930          NaN
# 1498.0     670-57-4549          Hawkins, Macy   21|7|1954          NaN
# 1499.0     166-84-2698           Reese Butler  30|10|1966          NaN
# 1500.0     366-03-5021        Declan Santiago   23|9|1934          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %% [markdown]
# # SSN

# %%
# remove extra spaces and other non-digit characters
new_ssn = [] # store ssn without space and non-digit characters
for ssn in list(dataCleansing_DF.SSN):
    temp_ssn = ''
    for char in ssn:
        if char.isdigit() == True: # check for digit
            temp_ssn = temp_ssn + char
    new_ssn.append(temp_ssn)

# %%
dataCleansing_DF['SSN'] = new_ssn # assign fresh ssn without space and non-digit characters
dataCleansing_DF
# Out:
#                 SSN                   Name   Birthdate  Current age  \
# Customer
# 1.0       539849599  Edith Emerson-Foster   26|10|1944          NaN
# 2.0       444054079          victor, BRETT    1|1|1932          NaN
# 3.0       418185649         QUINN, Freddie   17|8|1973          NaN
# 4.0       065633311          Foster, Chris    2|8|1947          NaN
# 5.0       059589566           Smith, Ryan    3|10|1948          NaN
# ...             ...                    ...         ...          ...
# 1496.0    347700762        Hancock, Quincy   28|9|1965          NaN
# 1497.0    638192849         Gibson, Ifeoma   31|7|1930          NaN
# 1498.0    670574549          Hawkins, Macy   21|7|1954          NaN
# 1499.0    166842698           Reese Butler  30|10|1966          NaN
# 1500.0    366035021        Declan Santiago   23|9|1934          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %%
# remove duplicate
dataCleansing_DF.drop_duplicates(subset=['SSN'],inplace=True)
dataCleansing_DF
# Out:
#                 SSN                   Name   Birthdate  Current age  \
# Customer
# 1.0       539849599  Edith Emerson-Foster   26|10|1944          NaN
# 2.0       444054079          victor, BRETT    1|1|1932          NaN
# 3.0       418185649         QUINN, Freddie   17|8|1973          NaN
# 4.0       065633311          Foster, Chris    2|8|1947          NaN
# 5.0       059589566           Smith, Ryan    3|10|1948          NaN
# ...             ...                    ...         ...          ...
# 1496.0    347700762        Hancock, Quincy   28|9|1965          NaN
# 1497.0    638192849         Gibson, Ifeoma   31|7|1930          NaN
# 1498.0    670574549          Hawkins, Macy   21|7|1954          NaN
# 1499.0    166842698           Reese Butler  30|10|1966          NaN
# 1500.0    366035021        Declan Santiago   23|9|1934          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %%
# remove rows that donot have 9 digits SSN
dataCleansing_DF.drop(dataCleansing_DF[dataCleansing_DF.SSN.str.len()!=9].index, inplace=True)
dataCleansing_DF
# Out:
#                 SSN                   Name   Birthdate  Current age  \
# Customer
# 1.0       539849599  Edith Emerson-Foster   26|10|1944          NaN
# 2.0       444054079          victor, BRETT    1|1|1932          NaN
# 3.0       418185649         QUINN, Freddie   17|8|1973          NaN
# 4.0       065633311          Foster, Chris    2|8|1947          NaN
# 5.0       059589566           Smith, Ryan    3|10|1948          NaN
# ...             ...                    ...         ...          ...
# 1496.0    347700762        Hancock, Quincy   28|9|1965          NaN
# 1497.0    638192849         Gibson, Ifeoma   31|7|1930          NaN
# 1498.0    670574549          Hawkins, Macy   21|7|1954          NaN
# 1499.0    166842698           Reese Butler  30|10|1966          NaN
# 1500.0    366035021        Declan Santiago   23|9|1934          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %%
# just for concept
dataCleansing_DF.SSN.str.len()
# Out:
# Customer
# 1.0       9
# 2.0       9
# 3.0       9
# 4.0       9
# 5.0       9
#          ..
# 1496.0    9
# 1497.0    9
# 1498.0    9
# 1499.0    9
# 1500.0    9
# Name: SSN, Length: 1441, dtype: int64

# %%
# just for concept
a=list(dataCleansing_DF.SSN)[0]
a
# Out:
# '539849599'

# %%
# just for concept,this is how we are formatting SSN
a[:3] +'-'+a[3:5]+'-'+a[5:]
# Out:
# '539-84-9599'

# %%
dataCleansing_DF.SSN = dataCleansing_DF.SSN.apply(lambda x : x[:3] +'-'+x[3:5]+'-'+x[5:])
dataCleansing_DF
# Out:
#                   SSN                   Name   Birthdate  Current age  \
# Customer
# 1.0       539-84-9599  Edith Emerson-Foster   26|10|1944          NaN
# 2.0       444-05-4079          victor, BRETT    1|1|1932          NaN
# 3.0       418-18-5649         QUINN, Freddie   17|8|1973          NaN
# 4.0       065-63-3311          Foster, Chris    2|8|1947          NaN
# 5.0       059-58-9566           Smith, Ryan    3|10|1948          NaN
# ...               ...                    ...         ...          ...
# 1496.0    347-70-0762        Hancock, Quincy   28|9|1965          NaN
# 1497.0    638-19-2849         Gibson, Ifeoma   31|7|1930          NaN
# 1498.0    670-57-4549          Hawkins, Macy   21|7|1954          NaN
# 1499.0    166-84-2698           Reese Butler  30|10|1966          NaN
# 1500.0    366-03-5021        Declan Santiago   23|9|1934          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %% [markdown]
# # BirthDate

# %%
dataCleansing_DF.dtypes # data type of birthdate is object
# Out:
# SSN               object
# Name              object
# Birthdate         object
# Current age      float64
# Region            object
# CredCardUser?      int64
# Income             int64
# Purchases          int64
# AmountSpent        int64
# dtype: object

# %%
# first replace '|' with '-'
dataCleansing_DF.Birthdate = dataCleansing_DF.Birthdate.apply(lambda x : x.replace('|','-'))
# now change the datatype to datetime
dataCleansing_DF['Birthdate'] = pd.to_datetime(dataCleansing_DF['Birthdate'])
# check the data type again for confirmation,whether its changed or not
dataCleansing_DF.dtypes
# Out:
# SSN                      object
# Name                     object
# Birthdate        datetime64[ns]
# Current age             float64
# Region                   object
# CredCardUser?             int64
# Income                    int64
# Purchases                 int64
# AmountSpent               int64
# dtype: object

# %% [markdown]
# # Income

# %%
dataCleansing_DF
# Out:
#                   SSN                   Name  Birthdate  Current age  \
# Customer
# 1.0       539-84-9599  Edith Emerson-Foster  1944-10-26          NaN
# 2.0       444-05-4079          victor, BRETT 1932-01-01          NaN
# 3.0       418-18-5649         QUINN, Freddie 1973-08-17          NaN
# 4.0       065-63-3311          Foster, Chris 1947-02-08          NaN
# 5.0       059-58-9566           Smith, Ryan  1948-03-10          NaN
# ...               ...                    ...        ...          ...
# 1496.0    347-70-0762        Hancock, Quincy 1965-09-28          NaN
# 1497.0    638-19-2849         Gibson, Ifeoma 1930-07-31          NaN
# 1498.0    670-57-4549          Hawkins, Macy 1954-07-21          NaN
# 1499.0    166-84-2698           Reese Butler 1966-10-30          NaN
# 1500.0    366-03-5021        Declan Santiago 1934-09-23          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %%
# remove rows with 9999
dataCleansing_DF.drop(dataCleansing_DF[dataCleansing_DF.Income==9999].index,inplace=True)
dataCleansing_DF
# Out:
#                   SSN                   Name  Birthdate  Current age  \
# Customer
# 1.0       539-84-9599  Edith Emerson-Foster  1944-10-26          NaN
# 2.0       444-05-4079          victor, BRETT 1932-01-01          NaN
# 3.0       418-18-5649         QUINN, Freddie 1973-08-17          NaN
# 4.0       065-63-3311          Foster, Chris 1947-02-08          NaN
# 5.0       059-58-9566           Smith, Ryan  1948-03-10          NaN
# ...               ...                    ...        ...          ...
# 1496.0    347-70-0762        Hancock, Quincy 1965-09-28          NaN
# 1497.0    638-19-2849         Gibson, Ifeoma 1930-07-31          NaN
# 1498.0    670-57-4549          Hawkins, Macy 1954-07-21          NaN
# 1499.0    166-84-2698           Reese Butler 1966-10-30          NaN
# 1500.0    366-03-5021        Declan Santiago 1934-09-23          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...

# %%
# correct the low income
dataCleansing_DF['Income'] = dataCleansing_DF.Income.apply(lambda x : x*1000 if x<1000 else x)
dataCleansing_DF
# Out:
#                   SSN                   Name  Birthdate  Current age  \
# Customer
# 1.0       539-84-9599  Edith Emerson-Foster  1944-10-26          NaN
# 2.0       444-05-4079          victor, BRETT 1932-01-01          NaN
# 3.0       418-18-5649         QUINN, Freddie 1973-08-17          NaN
# 4.0       065-63-3311          Foster, Chris 1947-02-08          NaN
# 5.0       059-58-9566           Smith, Ryan  1948-03-10          NaN
# ...               ...                    ...        ...          ...
# 1496.0    347-70-0762        Hancock, Quincy 1965-09-28          NaN
# 1497.0    638-19-2849         Gibson, Ifeoma 1930-07-31          NaN
# 1498.0    670-57-4549          Hawkins, Macy 1954-07-21          NaN
# 1499.0    166-84-2698           Reese Butler 1966-10-30          NaN
# 1500.0    366-03-5021        Declan Santiago 1934-09-23          NaN
#
#                       Region  CredCardUser?  Income  Purchases  AmountSpent
# Customer
# ...
