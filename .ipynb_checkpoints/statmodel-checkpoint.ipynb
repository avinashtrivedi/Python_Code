# %%
import pandas as pd

# %%
df = pd.read_csv('listings.csv')

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df = df[['neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates','bedrooms', 'beds', 'minimum_nights', 'maximum_nights','availability_365', 'number_of_reviews','review_scores_location']]

# %%
df
# Out:
#                        neighbourhood_cleansed              property_type  \
# 0      Oostelijk Havengebied - Indische Buurt  Private room in apartment
# 1                                Centrum-Oost  Private room in townhouse
# 2                                Centrum-West           Entire apartment
# 3                                Centrum-West  Private room in houseboat
# 4                                Centrum-Oost  Private room in apartment
# ...                                       ...                        ...
# 18517                            Centrum-Oost           Entire apartment
# 18518                            Centrum-Oost           Entire apartment
# 18519                 De Pijp - Rivierenbuurt           Entire apartment
# 18520                            Centrum-Oost  Private room in apartment
# 18521  Oostelijk Havengebied - Indische Buurt       Private room in boat
#
#              room_type  accommodates  bedrooms  beds  minimum_nights  \
# ...

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-14-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
X = df.iloc[:, 3:-1].values
y = df.iloc[:, -1].values
X.shape
# Out:
# (15019, 7)

# %%
import statsmodels.api as sm
import numpy as np
X = np.append(arr=np.ones((15019, 1)).astype(int), values=X, axis=1)
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.977
# Date:                Mon, 10 May 2021   Prob (F-statistic):           1.57e-05
# Time:                        09:42:21   Log-Likelihood:                -15840.
# No. Observations:               15019   AIC:                         3.169e+04
# Df Residuals:                   15013   BIC:                         3.174e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.5930      0.017    581.378      0.000       9.561       9.625
# ...
