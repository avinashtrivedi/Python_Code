# %%
# import the library
import pandas as pd
import matplotlib.pyplot as plt

# read the dataset
df = pd.read_csv('listings.csv')

# %%
# display few rows
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
# ...

# %% [markdown]
# # Task:1
# -------------------

# %% [markdown]
# # Step:1

# %%
# Compute pairwise correlation
df.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.527680  0.006060  -0.018406
# host_id                         0.527680  1.000000  0.007230  -0.047042
# latitude                        0.006060  0.007230  1.000000  -0.107228
# longitude                      -0.018406 -0.047042 -0.107228   1.000000
# price                           0.030992  0.037808  0.002181  -0.042662
# minimum_nights                 -0.041777 -0.028396  0.011863  -0.026450
# number_of_reviews              -0.308877 -0.148577  0.037973  -0.020905
# reviews_per_month               0.250475  0.203368  0.042594  -0.041718
# calculated_host_listings_count  0.038248 -0.048570  0.039785  -0.044122
# availability_365               -0.059485 -0.009365  0.012116  -0.086532
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.030992       -0.041777          -0.308877
# ...

# %% [markdown]
# # Step:2

# %%
# get the correlation of number_of_reviews with respect to other columns
df.corr()['number_of_reviews'].sort_values(ascending = False)
# Out:
# number_of_reviews                 1.000000
# reviews_per_month                 0.556738
# availability_365                  0.277621
# calculated_host_listings_count    0.085898
# latitude                          0.037973
# price                            -0.001235
# longitude                        -0.020905
# minimum_nights                   -0.021685
# host_id                          -0.148577
# id                               -0.308877
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# # Step:3

# %%
new_df = df[['number_of_reviews','reviews_per_month','availability_365']]

# %%
# plot the scatter_matrix
pd.plotting.scatter_matrix(new_df,figsize=(10,7))
plt.show()

# %% [markdown]
# # Task:2
# -----------

# %% [markdown]
# # Step:1

# %%
df.isna().any() # check if there is missing value/NaN in any column
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %%
#  total number of missing values for each column
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# # Step:2

# %% [markdown]
# # 'name', 'host_name', 'last_review', 'reviews_per_month'

# %%
NaNColumn = df.columns[df.isna().any()].tolist() # column name containing NaN as list
NaNColumn
# Out:
# ['name', 'host_name', 'last_review', 'reviews_per_month']

# %%
print(*NaNColumn,sep=',') # print column name
# Out:
# name,host_name,last_review,reviews_per_month

# %% [markdown]
# # Step:3

# %%
# fill Nan with average value
df['reviews_per_month'] = df['reviews_per_month'].fillna(df['reviews_per_month'].mean())
