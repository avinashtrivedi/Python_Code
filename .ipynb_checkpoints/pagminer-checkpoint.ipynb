# %%
import pandas as pd

# %%
url="https://philchodrow.github.io/PIC16A/datasets/gapminder.csv"

# %%
gapminder = pd.read_csv(url)
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
a = gapminder[gapminder['continent']=='Asia']

# %%
a['country'].value_counts()
# Out:
# Vietnam               12
# Bahrain               12
# China                 12
# Mongolia              12
# Indonesia             12
# Oman                  12
# Saudi Arabia          12
# Syria                 12
# Philippines           12
# Israel                12
# Hong Kong, China      12
# Afghanistan           12
# India                 12
# Kuwait                12
# Korea, Dem. Rep.      12
# Japan                 12
# Thailand              12
# West Bank and Gaza    12
# Jordan                12
# Pakistan              12
# Lebanon               12
# Yemen, Rep.           12
# Sri Lanka             12
# Iraq                  12
# Korea, Rep.           12
# Nepal                 12
# Bangladesh            12
# Taiwan                12
# Singapore             12
# Myanmar               12
# Malaysia              12
# Iran                  12
# Cambodia              12
# Name: country, dtype: int64

# %%
b=a[['lifeExp']]
b1=a[['lifeExp']]-10
b2=a[['lifeExp']]-20

grp.groupby('year')['lifeExp'].count().to_dict()

# %%
a.groupby(['country'])[['year','lifeExp']].apply(lambda grp: list(grp.value_counts().index))

# %%
t

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t.values())

# %%
a.groupby(by=['country']).mean()
# Out:
#                       year    lifeExp           pop     gdpPercap
# country
# Afghanistan         1979.5  37.478833  1.582372e+07    802.674598
# Bahrain             1979.5  65.605667  3.739132e+05  18077.663945
# Bangladesh          1979.5  49.834083  9.075540e+07    817.558818
# Cambodia            1979.5  47.902750  8.510431e+06    675.367824
# China               1979.5  61.785140  9.581601e+08   1488.307694
# Hong Kong, China    1979.5  73.492833  4.792259e+06  16228.700865
# India               1979.5  53.166083  7.011307e+08   1057.296307
# Indonesia           1979.5  54.335750  1.483228e+08   1741.365360
# Iran                1979.5  58.636583  4.230171e+07   7376.582905
# Iraq                1979.5  56.581750  1.418750e+07   7811.809117
# Israel              1979.5  73.645833  3.845611e+06  14160.936434
# Japan               1979.5  74.826917  1.117588e+08  17750.869984
# Jordan              1979.5  59.786417  2.667973e+06   3128.120762
# ...

# %%
f = a.groupby(by=['country'])['year','lifeExp']
# f.sort('Frequency',ascending=False, inplace=True)
# Out:
# <ipython-input-45-b6a72c4f4a34>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   f = a.groupby(by=['country'])['year','lifeExp']

# %%
a.groupby(['country'])['year','lifeExp'].apply(lambda grp: list(grp.value_counts().index))
# Out:
# <ipython-input-41-468c64322851>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a.groupby(['country'])['year','lifeExp'].apply(lambda grp: list(grp.value_counts().index))
# country
# Afghanistan           [(2007, 43.828), (2002, 42.129), (1997, 41.763...
# Bahrain               [(2007, 75.635), (2002, 74.795), (1997, 73.925...
# Bangladesh            [(2007, 64.062), (2002, 62.013000000000005), (...
# Cambodia              [(2007, 59.723), (2002, 56.751999999999995), (...
# China                 [(2007, 72.961), (2002, 72.028), (1997, 70.426...
# Hong Kong, China      [(2007, 82.208), (2002, 81.495), (1997, 80.0),...
# India                 [(2007, 64.69800000000001), (2002, 62.879), (1...
# Indonesia             [(2007, 70.65), (2002, 68.58800000000001), (19...
# Iran                  [(2007, 70.964), (2002, 69.45100000000001), (1...
# ...

# %%
list(a[a['country'] == 'Taiwan'][['year','lifeExp']].value_counts().index)
# Out:
# [(2007, 78.4),
#  (2002, 76.99),
#  (1997, 75.25),
#  (1992, 74.26),
#  (1987, 73.4),
#  (1982, 72.16),
#  (1977, 70.59),
#  (1972, 69.39),
#  (1967, 67.5),
#  (1962, 65.2),
#  (1957, 62.4),
#  (1952, 58.5)]

# %%
df.groupby(['Type'])['Name'].apply(lambda grp: list(grp.value_counts().index)).to_dict()

# %%
df.groupby(['Type']).apply(lambda grp: grp.groupby('Name')['Type'].count().to_dict()).to_dict()
