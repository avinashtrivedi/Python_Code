# %%
# import library
import pandas as pd

# %%
# source of dataset 
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-10-2021.csv
rdf = pd.read_csv('covid_data.csv')

# %%
rdf = rdf.iloc[:,3:] # consider only important columns

# %%
rdf.head(5) # display top 5 rows
# Out:
#   Country_Region          Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  2021-05-11 04:20:41  33.93911  67.709953      62063    2698
# 1        Albania  2021-05-11 04:20:41  41.15330  20.168300     131753    2416
# 2        Algeria  2021-05-11 04:20:41  28.03390   1.659600     124288    3335
# 3        Andorra  2021-05-11 04:20:41  42.50630   1.521800      13429     127
# 4         Angola  2021-05-11 04:20:41 -11.20270  17.873900      28875     636
#
#    Recovered   Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0    54382.0   4983.0  Afghanistan     159.428834             4.347196
# 1   118041.0  11296.0      Albania    4578.254222             1.833734
# 2    86554.0  34399.0      Algeria     283.432255             2.683284
# 3    13021.0    281.0      Andorra   17380.443927             0.945714
# 4    24772.0   3467.0       Angola      87.856035             2.202597

# %%
# create pivot table
country_deaths = rdf.pivot_table('Deaths',index='Country_Region').sort_values(by='Deaths',ascending=False)
country_deaths
# Out:
#                         Deaths
# Country_Region
# Iran                   75261.0
# Poland                 70034.0
# Argentina              67821.0
# South Africa           54825.0
# Indonesia              47218.0
# ...                        ...
# Saint Kitts and Nevis      0.0
# Holy See                   0.0
# Micronesia                 0.0
# Marshall Islands           0.0
# Dominica                   0.0
#
# [192 rows x 1 columns]

# %% [markdown]
# # display all rows

# %%
len(list(country_deaths))
# Out:
# 1

# %%
country_deaths.shape[0]
# Out:
# 192

# %%
# set number of rows to be displayed
pd.set_option('display.max_rows',len(country_deaths))
# set number of columns to be displayed
pd.set_option('display.max_columns',len(list(country_deaths)))

country_deaths
# Out:
#                                         Deaths
# Country_Region
# Iran                              75261.000000
# Poland                            70034.000000
# Argentina                         67821.000000
# South Africa                      54825.000000
# Indonesia                         47218.000000
# Turkey                            43311.000000
# Czechia                           29711.000000
# Romania                           29034.000000
# Hungary                           28693.000000
# Ecuador                           19242.000000
# Philippines                       18562.000000
# Bulgaria                          17045.000000
# Portugal                          16993.000000
# Iraq                              15800.000000
# Brazil                            15675.148148
# Egypt                             13972.000000
# Bolivia                           13228.000000
# Slovakia                          12051.000000
# Bangladesh                        11972.000000
# ...

# %%
# reset the number of rows and columns to their default value
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %%
totals = country_deaths.groupby('Country_Region')["Deaths"].sum().sort_values()
totals
# Out:
# Country_Region
# Samoa                   0.0
# Marshall Islands        0.0
# Solomon Islands         0.0
# Micronesia              0.0
# Dominica                0.0
#                      ...
# Indonesia           47218.0
# South Africa        54825.0
# Argentina           67821.0
# Poland              70034.0
# Iran                75261.0
# Name: Deaths, Length: 192, dtype: float64

# %%
plt.figure(figsize=(5,50)) # set the figure size
totals.plot(kind='barh',fontsize=10,color='r')
plt.xticks(rotation='vertical')
plt.show() # plot the graph

# %%
rdf.head()
# Out:
#   Country_Region          Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  2021-05-11 04:20:41  33.93911  67.709953      62063    2698
# 1        Albania  2021-05-11 04:20:41  41.15330  20.168300     131753    2416
# 2        Algeria  2021-05-11 04:20:41  28.03390   1.659600     124288    3335
# 3        Andorra  2021-05-11 04:20:41  42.50630   1.521800      13429     127
# 4         Angola  2021-05-11 04:20:41 -11.20270  17.873900      28875     636
#
#    Recovered   Active Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 0    54382.0   4983.0  Afghanistan     159.428834             4.347196
# 1   118041.0  11296.0      Albania    4578.254222             1.833734
# 2    86554.0  34399.0      Algeria     283.432255             2.683284
# 3    13021.0    281.0      Andorra   17380.443927             0.945714
# 4    24772.0   3467.0       Angola      87.856035             2.202597

# %%
recovereddf = rdf['Confirmed'] -  rdf['Deaths']
recovereddf
# Out:
# 0        59365
# 1       129337
# 2       120953
# 3        13302
# 4        28239
#          ...
# 3978      3454
# 3979    298871
# 3980      5210
# 3981     90855
# 3982     36857
# Length: 3983, dtype: int64

# %%
rdf = rdf.groupby('Country_Region').sum().reset_index()

# %%
rdf.columns
# Out:
# Index(['Country_Region', 'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')

# %%
rdf.columns = ['location', 'Lat', 'Long_', 'total_cases', 'total_deaths', 'Recovered',
       'Active', 'Incident_Rate', 'Case_Fatality_Ratio']

# %%
rdf = rdf.iloc[:,[0,1,2,3,4,7,8]]

# %%
# testing dataframe
rdf
# Out:
#                location        Lat       Long_  total_cases  total_deaths  \
# 0           Afghanistan  33.939110   67.709953        62063          2698
# 1               Albania  41.153300   20.168300       131753          2416
# 2               Algeria  28.033900    1.659600       124288          3335
# 3               Andorra  42.506300    1.521800        13429           127
# 4                Angola -11.202700   17.873900        28875           636
# ..                  ...        ...         ...          ...           ...
# 187             Vietnam  14.058324  108.277199         3489            35
# 188  West Bank and Gaza  31.952200   35.233200       302249          3378
# 189               Yemen  15.552727   48.516388         6485          1275
# 190              Zambia -13.133897   27.849332        92112          1257
# 191            Zimbabwe -19.015438   29.154857        38433          1576
#
#      Incident_Rate  Case_Fatality_Ratio
# ...

# %%
recovereddf = rdf['total_cases'] -  rdf['total_deaths']
recovereddf
# Out:
# 0       59365
# 1      129337
# 2      120953
# 3       13302
# 4       28239
#         ...
# 187      3454
# 188    298871
# 189      5210
# 190     90855
# 191     36857
# Length: 192, dtype: int64

# %%
type(recovereddf)
# Out:
# pandas.core.series.Series

# %%
countriesdf = rdf['location']
countriesdf
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
#               ...
# 187               Vietnam
# 188    West Bank and Gaza
# 189                 Yemen
# 190                Zambia
# 191              Zimbabwe
# Name: location, Length: 192, dtype: object

# %%
final = [countriesdf,recovereddf]
pd.concat(final,axis=1)
# Out:
#                location       0
# 0           Afghanistan   59365
# 1               Albania  129337
# 2               Algeria  120953
# 3               Andorra   13302
# 4                Angola   28239
# ..                  ...     ...
# 187             Vietnam    3454
# 188  West Bank and Gaza  298871
# 189               Yemen    5210
# 190              Zambia   90855
# 191            Zimbabwe   36857
#
# [192 rows x 2 columns]

# %%
# reference https://www.pythonpool.com/matplotlib-barh/
plt.figure(figsize=(5,50)) # set the figure size
plt.barh(countriesdf,recovereddf,color='r')
# to avoid scientific notation eg. le7
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation='vertical')
plt.show() # plot the graph
