# %%
import pandas as pd

# %%
df1 = pd.read_csv('station_information.csv')

# %%
df2 = pd.read_csv('station_status.csv')

# %%
df1
# Out:
#      station_id                           name  capacity      lat      lon  \
# 0            72               W 52 St & 11 Ave        39  40.7673 -73.9939
# 1            79       Franklin St & W Broadway        33  40.7191 -74.0067
# 2            82         St James Pl & Pearl St        27  40.7112 -74.0002
# 3            83  Atlantic Ave & Fort Greene Pl        62  40.6838 -73.9763
# 4           119       Park Ave & St Edwards St        19  40.6961 -73.9780
# ..          ...                            ...       ...      ...      ...
# 762        3689       W 104 St & Amsterdam Ave        47  40.7990 -73.9665
# 763        3690            Park Pl & Church St        36  40.7133 -74.0094
# 764        3691                 28 Ave & 44 St        19  40.7641 -73.9107
# 765        3692               5 St & Market St        15  40.7000 -73.9744
# 766        3693             N 11 St & Kent Ave        27  40.7225 -73.9592
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
impact = df1['name']
Occurrences = df1['capacity']
plt.figure(figsize=(100,50))
plt.hist(Occurrences, bins=50)
plt.xticks(Occurrences,impact,rotation='vertical',fontsize=50)
plt.xlabel('Citi Bike Station',fontsize=50)
plt.ylabel('Occurrences',fontsize=50)
plt.title('Histogram',fontsize=50)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df1['lon'],df1['lat'])
plt.show()

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-70df42b71b37> in <module>
#       1 import pandas as pd
# ----> 2 from shapely.geometry import Point
#       3 import geopandas as gpd
#       4 from geopandas import GeoDataFrame
#
# ModuleNotFoundError: No module named 'shapely'
