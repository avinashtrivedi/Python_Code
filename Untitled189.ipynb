# %%
import pandas as pd

# %%
df = pd.read_csv('20229970118.csv')

# %%
df[df['Deposit'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [Date, Description, BrCd, Withdrawal, Deposit, Balance]
# Index: []

# %%
df
# Out:
#          Date                                        Description   BrCd  \
# 0    01-01-15  TRF TO 3199608162090  /INB AMAZON SELLER SERVI...  99922
# 1    04-01-15  TRF FROM 3197896044308  /IMPS18/500413009918/X...   4430
# 2    04-01-15          TRF TO 0034566726322  /INB E-TDR/E-STDR    99922
# 3    08-01-15                           TRF TO 0034026819166       9985
# 4    08-01-15  TRF TO 0031819363884  /INB IRCTC-RAILWAY TICKE...  99922
# ..        ...                                                ...    ...
# 707  07-03-17  TRF TO 3199587162090  /INB HDFC BANK CREDIT CA...  99922
# 708  07-03-17          TRF TO 0036609960770  /INB E-TDR/E-STDR    99922
# 709  07-03-17                       TRF TO 3199631162092  /INB    99922
# 710  09-03-17              TRF TO 0030202582655  /INB SBI CAPS    99922
# 711  10-03-17  TRF FROM 0030230175497  /INB -FT ISSUED FOR CR...  99922
#
#     Withdrawal    Deposit    Balance
# 0       194.30        NaN  10,208.76
# ...
