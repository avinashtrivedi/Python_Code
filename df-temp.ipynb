# %%
# import the library
import pandas as pd

# %%
# load the dataset
df = pd.read_csv('IthacaDailyClimate2018.csv')

# %%
# an expression to extract a new dataframe containing those days 
# where the temperature reached at least 70 degrees
at_least_70 = df[df['Maximum Temperature']>=70]

# expression that computes how many days reached at least 70 degrees
num_at_least_70 = len(at_least_70)

# %%
at_least_70
# Out:
#            Date  Maximum Temperature  Minimum Temperature  \
# 121  05-02-2018                   78                   34
# 122  05-03-2018                   85                   55
# 123  05-04-2018                   80                   60
# 124  05-05-2018                   81                   38
# 125  05-06-2018                   74                   43
# ..          ...                  ...                  ...
# 279  10-07-2018                   71                   59
# 281  10-09-2018                   77                   55
# 282  10-10-2018                   80                   62
# 283  10-11-2018                   78                   61
# 284  10-12-2018                   73                   45
#
#      Average Temperature  Precipitation  Snowfall  Snow Depth
# 121                 56.0           0.00       0.0           0
# 122                 70.0           0.00       0.0           0
# 123                 70.0           0.07       0.0           0
# ...

# %%
num_at_least_70
# Out:
# 130
