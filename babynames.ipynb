# %%
# import the library
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# read the table from the html webpage
df = pd.read_html("https://www.ssa.gov/OACT/babynames/decades/names2010s.html")

# %%
# clean the dataframe
df = df[0]
df = df[:-1]

# %%
# 'Unnamed: 0_level_0' represents rank column
#  make its data type integer
df['Unnamed: 0_level_0'] = df['Unnamed: 0_level_0'].astype('int')

# create dataframe for male and female
df_male = pd.concat([df['Unnamed: 0_level_0'],df['Males']],axis=1)
df_female = pd.concat([df['Unnamed: 0_level_0'],df['Females']],axis=1)

# %%
df_male
# Out:
#      Rank     Name  Number
# 0       1     Noah  182993
# 1       2     Liam  173717
# 2       3    Jacob  162958
# 3       4  William  159697
# 4       5    Mason  157652
# ..    ...      ...     ...
# 195   196  Bradley   20128
# 196   197   Cayden   19729
# 197   198   Xander   19270
# 198   199   Graham   19239
# 199   200    Rowan   18991
#
# [200 rows x 3 columns]

# %%
df_female
# Out:
#      Rank      Name  Number
# 0       1      Emma  194755
# 1       2    Olivia  184291
# 2       3    Sophia  180896
# 3       4  Isabella  170265
# 4       5       Ava  155606
# ..    ...       ...     ...
# 195   196     Amaya   16230
# 196   197   Emerson   16216
# 197   198  Julianna   16165
# 198   199   Cecilia   16125
# 199   200  Izabella   16006
#
# [200 rows x 3 columns]

# %%
# append both the dataframe
df_mf = df_male.append(df_female)

# reset the index so that index starts from zero
df_mf.reset_index(drop=True,inplace=True)

# %%
df_mf
# Out:
#      Rank      Name  Number
# 0       1      Noah  182993
# 1       2      Liam  173717
# 2       3     Jacob  162958
# 3       4   William  159697
# 4       5     Mason  157652
# ..    ...       ...     ...
# 395   196     Amaya   16230
# 396   197   Emerson   16216
# 397   198  Julianna   16165
# 398   199   Cecilia   16125
# 399   200  Izabella   16006
#
# [400 rows x 3 columns]

# %%
# filter the dataframe to contain only names 
# that start with 'C' or contain a letter 'X' or 'x' 

df_mf = df_mf[df_mf['Name'].apply(lambda name:
                                  name.startswith('C') 
                                  or ('X' in name) 
                                  or ('x' in name)
                                 )]

# %%
df_mf
# Out:
#      Rank         Name  Number
# 7       8    Alexander  141899
# 26     27  Christopher  101919
# 29     30       Carter   95090
# 37     38        Caleb   86573
# 40     41    Christian   83994
# 48     49      Charles   69898
# 51     52        Jaxon   69008
# 52     53       Connor   68199
# 56     57      Cameron   66101
# 67     68       Colton   58377
# 79     80        Chase   50228
# 82     83       Cooper   49215
# 84     85       Xavier   48596
# 86     87       Carson   47940
# 92     93       Jaxson   42287
# 108   109         Cole   36361
# 110   111       Carlos   35251
# 114   115          Max   34097
# 119   120         Alex   32524
# 120   121      Maxwell   32407
# 121   122         Axel   31749
# 127   128      Braxton   30248
# 131   132       Camden   29670
# 153   154       Maddox   25638
# 165   166        Colin   24701
# 179   180       Calvin   23049
# 181   182        Caden   22342
# 196   197       Cayden   19729
# 197   198       Xander   19270
# 208     9    Charlotte  102339
# 214    15        Chloe   85160
# 231    32       Camila   57849
# 241    42       Claire   47691
# 253    54        Alexa   41971
# 259    60       Alexis   40314
# 262    63     Caroline   39590
# 294    95    Alexandra   30936
# 309   110         Cora   27778
# 318   119        Clara   26621
# 348   149       Ximena   21011
# 386   187    Catherine   17124
# 398   199      Cecilia   16125

# %%
# check its datatype
df_mf.dtypes
# Out:
# Rank       int32
# Name      object
# Number    object
# dtype: object

# %%
# convert the datatype of 'Number' from object to int
df_mf['Number'] = df_mf['Number'].astype('int')

# %%
# check its datatype
df_mf.dtypes
# Out:
# Rank       int32
# Name      object
# Number     int32
# dtype: object

# %%
# sort the dataframe on the basis of Number
df_mf.sort_values('Number',ascending=False,inplace=True)

# reset the index so that index starts from zero
df_mf.reset_index(drop=True,inplace=True)

# %% [markdown]
# # first  10 rows

# %%
df_mf.head(10)
# Out:
#    Rank         Name  Number
# 0     8    Alexander  141899
# 1     9    Charlotte  102339
# 2    27  Christopher  101919
# 3    30       Carter   95090
# 4    38        Caleb   86573
# 5    15        Chloe   85160
# 6    41    Christian   83994
# 7    49      Charles   69898
# 8    52        Jaxon   69008
# 9    53       Connor   68199

# %% [markdown]
# # sum of the number

# %%
# Dataframe that contain names that start with 'C' 
df_C = df_mf[df_mf['Name'].apply(lambda name: name.startswith('C'))]
df_C
# Out:
#     Rank         Name  Number
# 1      9    Charlotte  102339
# 2     27  Christopher  101919
# 3     30       Carter   95090
# 4     38        Caleb   86573
# 5     15        Chloe   85160
# 6     41    Christian   83994
# 7     49      Charles   69898
# 9     53       Connor   68199
# 10    57      Cameron   66101
# 11    68       Colton   58377
# 12    32       Camila   57849
# 13    80        Chase   50228
# 14    83       Cooper   49215
# 16    87       Carson   47940
# 17    42       Claire   47691
# 21    63     Caroline   39590
# 22   109         Cole   36361
# 23   111       Carlos   35251
# 30   132       Camden   29670
# 31   110         Cora   27778
# 32   119        Clara   26621
# 34   166        Colin   24701
# 35   180       Calvin   23049
# 36   182        Caden   22342
# 38   197       Cayden   19729
# 40   187    Catherine   17124
# 41   199      Cecilia   16125

# %%
# sum of the number of the 'C' names 
print(df_C['Number'].sum())
# Out:
# 1388914

# %%
# DataFrame with the names that contain a letter 'X' or 'x' 
df_Xx = df_mf[df_mf['Name'].apply(lambda name: ('X' in name) or ('x' in name))]
df_Xx
# Out:
#     Rank       Name  Number
# 0      8  Alexander  141899
# 8     52      Jaxon   69008
# 15    85     Xavier   48596
# 18    93     Jaxson   42287
# 19    54      Alexa   41971
# 20    60     Alexis   40314
# 24   115        Max   34097
# 25   120       Alex   32524
# 26   121    Maxwell   32407
# 27   122       Axel   31749
# 28    95  Alexandra   30936
# 29   128    Braxton   30248
# 33   154     Maddox   25638
# 37   149     Ximena   21011
# 39   198     Xander   19270

# %%
# sum of the number of names with 'X' or 'x'
print(df_Xx['Number'].sum())
# Out:
# 641955
