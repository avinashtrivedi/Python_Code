# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('train.csv')

# %%
pd.set_option('display.max_columns', 35)
dataset
# Out:
#       F1  F2  F3  F4  F5  F6  F7  F8  F9  F10    F11      F12  F13     F14  \
# 0     35   2  32   1   1   1   1   2   1    1   4621  4646359   11  151135
# 1     49   1  29   1   1   2   1   1   2    2   6928  4711988   14  206506
# 2     33   2  27   2   2   1   2   1   1    1   7666  4137761   12  110251
# 3     32   2  35   2   2   2   1   1   1    1  10240  4953619   15  107047
# 4     49   1  23   2   2   1   2   2   1    1   4542  4670848   10  180843
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...    ...      ...  ...     ...
# 1033  55   1  30   2   2   2   1   2   1    1   9369  4259591   14  111018
# 1034  34   1  28   2   1   2   2   1   2    1  11951  4679689   15  120161
# 1035  51   2  28   2   1   2   2   2   1    1   6448  3921586   12  105382
# 1036  41   1  34   2   2   2   2   2   2    1   7376  3932014   15  149153
# 1037  51   2  35   1   1   1   1   2   1    2   5828  4782262   13  196623
#
# ...

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, -1].values

# %%
# library for one hot encoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
# [1] represent column number which you want to encode
# Product Container is the 1st column (index starts from zero) in the dataset 
transform = ColumnTransformer([('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [4])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [6])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [8])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [10])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [12])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [14])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
transform = ColumnTransformer([('encoder', OneHotEncoder(), [16])], remainder='passthrough')
X = np.array(transform.fit_transform(X), dtype = np.str)

# %%
X
# Out:
# array([['1.0', '0.0', '1.0', ..., '460243.0', '337225.0', '3.0'],
#        ['0.0', '1.0', '0.0', ..., '5.0', '5.0', '9.0'],
#        ['1.0', '0.0', '1.0', ..., '315957.0', '427125.0', '6.0'],
#        ...,
#        ['1.0', '0.0', '1.0', ..., '5.0', '5.0', '16.0'],
#        ['1.0', '0.0', '0.0', ..., '335217.0', '192369.0', '11.0'],
#        ['0.0', '1.0', '1.0', ..., '5.0', '5.0', '9.0']], dtype='<U32')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a80ceaa915ae> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0, random_state = 0)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
# -> 2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
#    2131                                               default_test_size=0.25)
#    2132
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1762     if (test_size_type == 'i' and (test_size >= n_samples or test_size <= 0)
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X)
# X_test = sc.transform(X)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 500, metric = 'minkowski', p = 2)
classifier.fit(X_train, y)
# Out:
# KNeighborsClassifier(n_neighbors=500)

# %%
scoring = 'accuracy'
from sklearn.model_selection import KFold, cross_validate,StratifiedKFold

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True)

# %%
cv_results = cross_validate(classifier, X, y, cv=kf, scoring=scoring, return_train_score=True)
cv_results
# Out:
# C:\Users\avitr\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# C:\Users\avitr\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# ...

# %%
from sklearn.model_selection import cross_validate

# %%
cv_results = cross_validate(lasso, X, y, cv=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b3ce9145d1d7> in <module>
# ----> 1 cv_results = cross_validate(lasso, X, y, cv=3)
#
# NameError: name 'lasso' is not defined
