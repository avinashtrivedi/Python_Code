# %%
# Name: Srinivas Patimedi
# Date:12/09/21
# Assignment:PasswordChecker3
print("PasswordChecker3 program developed by:Srinivas Patimedi")
import datetime
def main():
    # import the module datetime

    PASSWORD_LOG_FILE = "password_log_srinivas_patimedi.txt"
    MIN_PASSWORD_LENGTH = 6
    MAX_PASSWORD_LENGTH = 10
    
    current_date_and_time = datetime.datetime.today()
    # input password
    password = input("Enter your Password: ")
    password_length = len(password)
    # open the file for writing
    file = open("PASSWORD_LOG_FILE", "w")
    #the purpose of using the while loop is to Iterate over a block of code as long as the condition is true
    while password_length < MIN_PASSWORD_LENGTH or password_length > MAX_PASSWORD_LENGTH:
        # print the error if the password violates our conditions
        print("Error! Password must be between 6 and 10 characters")
        password = input("Enter your Password: ")
        if password_length < MIN_PASSWORD_LENGTH:
            reason_password_invalid = "Password < 6"
             # keep log if the password is less than 6 characters
            file.write(("{d}, {a}").format(d=current_date_and_time, a=reason_password_invalid))
        else:
            reason_password_invalid = "Password > 10"
                # keep log if the password is more than 10 characters
            file.write(("{d}, {b}").format(d=current_date_and_time, b=reason_password_invalid))
            # This creates a new line everytime a log is kept
            file.write("\n")
        # while True:

            # be low, you will have to input the password again as we are in while loop that should satisfy
            # the condition len(password)>=MIN_PASSWORD_LENGTH and len(password)<MAX_PASSWORD_LENGTH) if not satisfied, we will keep
            # inputting the password,
        print("Error! Password Invalid. Please Enter Again")
        password = input("Enter your Password: ")
        PASSWORD_LOG_FILE.close()

            #     a = "Password < 6"
            #     # keep log if the password is less than 6 characters
            #     file.write(("{d}, {a}").format(d=datetime.datetime.today(), a=a))
            # elif password_length > MAX_PASSWORD_LENGTH:
            #     b = "Password > 10"
            #     # keep log if the password is more than 10 characters
            #     file.write(("{d}, {b}").format(d=datetime.datetime.today(), b=b))
            # file.write("\n")
        # if password_length >= MIN_PASSWORD_LENGTH and password_length < MAX_PASSWORD_LENGTH:
        #         # when the condition is satisfied, then check the status of the password
        #         if password.isnumeric() == True:
        #             print("password is weak - contains only numbers")
        #
        #         elif password.isalpha() == True:
        #             print("password is weak - contains only letters")
        #
        #         else:
        #             print("password is strong - contains letters and numbers")
        #
        #         # break
    # the code below will be implemented if the password does not satisfy
    # the condition in the if statement
    # else:
        if password.isnumeric() == True:
            print("password is weak - contains only numbers")

        elif password.isalpha() == True:
            print("password is weak - contains only letter")

        else:
            print("password is strong - contains letters and numbers")
    # close the file
    file.close()
    # then open it up for reading
    input_file = open("PASSWORD_LOG_FILE", "r")
    # The purpose of using the for loop is to read the lines of the file, and print each line out
    for line in input_file:
        print(line, end='')
    input_file.close()

main()
# Out:
# PasswordChecker3 program developed by:Srinivas Patimedi
# Enter your Password: A@5005157
