# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('gapminder.csv')
a = df.groupby(['country']).apply(lambda x:x)

# %%
g = sns.relplot(
    data=a,
    kind="line",
    x="year",
    y="gdpPercap",
    hue="continent",
    col="continent",
    units="country",
    estimator=None,
    col_wrap=3
)

g.set(yscale="log")

# %%
c={'Asia':'blue',
   'Africa':'green',
   'Europe':'yellow',
   'Americas':'orange',
   'Oceania':'deeppink'
  }

from matplotlib.colors import LogNorm
fgrid = sns.relplot(data=a,
                   x='year',
                   y='gdpPercap',
                   col='continent',
                   hue="continent",
                   kind='line',
                   col_wrap=3,
#                     style='continent',
#                  palette=['b','darkorange','g','r','m'],
                 size= "country",
                 legend=True,
                    ci= None,
#                  size_norm=LogNorm(),
#                  facet_kws=dict(legend_out=True)
                   )



# leg = fgrid._legend
# for t in leg.texts:
#     # truncate label text to 4 characters
#     t.set_text(t.get_text()[:4])
    
    

# # title
# new_title = 'My title'
# fgrid._legend.set_title(new_title)
# # replace labels
# new_labels = ['label 1', 'label 2']
# for t, l in zip(fgrid._legend.texts, new_labels): t.set_text(l)

# sns.plt.show()



    
    
# fgrid._legend.set_label='hh'

# import matplotlib

# patches = [matplotlib.patches.Patch(color=v, label=k) for k,v in c.items()]
# matplotlib.pyplot.legend(handles=patches)

# for ax in fgrid.axes.flat:
#     labels = ax.get_yticklabels() # get x labels
# #     ax.ylim(hight=100000)
#     ax.set_yticks(ticks=[0,10,10**2,10**3,10**4,10**5]) # set new labels
# #     ax.set_xticklabels(fontsize=8, rotation=45, labels=header_name)


# fgrid.legend(title="Delivery Type");
   
    
# for i in range(7,149):
#     fgrid._legend.texts[i].set_text("")
# fgrid.fig.autofmt_xdate()
# fgrid.
# fgrid.set(ylim=(0, 100000))
# fgrid.set_yticks(list(range(30,91,10)))
# fgrid.map(sns.lineplot, "year", "gdpPercap")

# fgrid.add_legend()
for ax in fgrid.axes.flatten():
    ax.semilogy()
    
#     ax.legend('hh')

# %%
data=a,
                   x='year',
                   y='gdpPercap',
                   col='continent',
                   hue="continent",
                   kind='line',
                   col_wrap=3,
#                     style='continent',
#                  palette=['b','darkorange','g','r','m'],
                 size= "country",
                 legend=True,
                    ci= None,
# Out:
#   File "<tokenize>", line 10
#     size= "country",
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
sns.lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# tips = sns.load_dataset("tips")

# cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
g = sns.lineplot(x="year", y="gdpPercap", hue="continent", size = 'country', data=a)
h,l = g.get_legend_handles_labels()
# plt.legend(h[0:3],l[0:3],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize=13)
plt.show(g)

# %%
fgrid._legend.remove
# Out:
# <bound method Artist.remove of <matplotlib.legend.Legend object at 0x00000279C14BB640>>

# %%
fgrid.legend(handles=handles[1:], labels=labels[1:], title="Whatever else")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8cc949a01e5a> in <module>
# ----> 1 fgrid.legend(handles=handles[1:], labels=labels[1:], title="Whatever else")
#
# NameError: name 'handles' is not defined

# %%
handles=handles[1:], labels=labels[1:], title="Whatever else")

# %%
handles, labels = fgrid.get_legend_handles_labels()

# %%
fgrid._legend.get_legend_handler()

# %%
fgrid._legend.get_label()

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
fmri = sns.load_dataset("fmri")
fig, ax = plt.subplots()
g = sns.lineplot(x="timepoint", y="signal", hue="event", data=fmri, ax=ax)
# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles=handles[1:], labels=labels[1:])

# %%
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])

# %%
handles

# %%
labels

# %%
fgrid._legend

# %%
type(ax)

# %%
type(fgrid)

# %%
fgrid._legend._set_artist_props

# %%
fgrid._legend.texts[0]
# Out:
# Text(0, 0, 'continent')

# %%
fgrid._legend.legendPatch.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d8ac937ae06b> in <module>
# ----> 1 fgrid._legend.legendPatch()
#
# TypeError: 'FancyBboxPatch' object is not callable

# %%
leg = fgrid._legend
for t in leg.texts:
    # truncate label text to 4 characters
    t.set_text(t.get_text()[:4])

# %%
leg.contains
# Out:
# <bound method Legend.contains of <matplotlib.legend.Legend object at 0x00000279C46627C0>>

# %%
# title
new_title = 'My title'
g._legend.set_title(new_title)
# replace labels
new_labels = ['label 1', 'label 2']
for t, l in zip(fgrid._legend.texts, new_labels): t.set_text(l)

sns.plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")

cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
g = sns.scatterplot(x="total_bill", y="sex", hue="smoker", size = 'tip',sizes=(320, 600), data=tips)
# h,l = g.get_legend_handles_labels()
# plt.legend(h[0:3],l[0:3],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize=13)
plt.show(g)

# %%
g.get_legend_handles_labels()
# Out:
# ([<matplotlib.collections.PathCollection at 0x279cb809d00>,
# ...
#  ['smoker', 'Yes', 'No', 'tip', '1.5', '3.0', '4.5', '6.0', '7.5', '9.0'])

# %%
fgrid._legend

# %%
 fgrid._legend =2

# %%
fgrid._legend._l

# %%
a = fgrid._legend.get_legend_handler_map()

# %%
a
# Out:
# {matplotlib.container.StemContainer: <matplotlib.legend_handler.HandlerStem at 0x279bf554340>,
#  matplotlib.container.ErrorbarContainer: <matplotlib.legend_handler.HandlerErrorbar at 0x279bf5543a0>,
#  matplotlib.lines.Line2D: <matplotlib.legend_handler.HandlerLine2D at 0x279bf5543d0>,
#  matplotlib.patches.Patch: <matplotlib.legend_handler.HandlerPatch at 0x279bf578c70>,
#  matplotlib.collections.LineCollection: <matplotlib.legend_handler.HandlerLineCollection at 0x279bf578d60>,
#  matplotlib.collections.RegularPolyCollection: <matplotlib.legend_handler.HandlerRegularPolyCollection at 0x279bf578e80>,
#  matplotlib.collections.CircleCollection: <matplotlib.legend_handler.HandlerCircleCollection at 0x279bf5820a0>,
#  matplotlib.container.BarContainer: <matplotlib.legend_handler.HandlerPatch at 0x279bf5821f0>,
#  tuple: <matplotlib.legend_handler.HandlerTuple at 0x279bf5824c0>,
# ...

# %%
fgrid._legend.get_children()

# %%
fgrid._legend.set_
