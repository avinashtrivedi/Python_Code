# %%
import urllib.request as urllib2
from bs4 import *
from urllib.parse  import urljoin


def crawl(pages, depth=None):
    indexed_url = [] # a list for the main and sub-HTML websites in the main website
    for i in range(depth):
        for page in pages:
            if page not in indexed_url:
                indexed_url.append(page)
                try:
                    c = urllib2.urlopen(page)
                except:
                    print( "Could not open %s" % page)
                    continue
                soup = BeautifulSoup(c.read())
                links = soup('a') #finding all the sub_links
                for link in links:
                    if 'href' in dict(link.attrs):
                        url = urljoin(page, link['href'])
                        if url.find("'") != -1:
                                continue
                        url = url.split('#')[0] 
                        if url[0:4] == 'http':
                                indexed_url.append(url)
        pages = indexed_url
    return indexed_url


pagelist=["https://en.wikipedia.org/wiki/Python_%28programming_language%29"]
urls = crawl(pagelist, depth=1)
print( urls )
# Out:
# ['https://en.wikipedia.org/wiki/Python_%28programming_language%29', 'https://en.wikipedia.org/wiki/Wikipedia:Good_articles', 'https://en.wikipedia.org/wiki/Python_%28programming_language%29', 'https://en.wikipedia.org/wiki/Python_%28programming_language%29', 'https://en.wikipedia.org/wiki/Python_(disambiguation)', 'https://en.wikipedia.org/wiki/File:Python_logo_and_wordmark.svg', 'https://en.wikipedia.org/wiki/Programming_paradigm', 'https://en.wikipedia.org/wiki/Multi-paradigm_programming_language', 'https://en.wikipedia.org/wiki/Object-oriented_programming', 'https://en.wikipedia.org/wiki/Python_%28programming_language%29', 'https://en.wikipedia.org/wiki/Procedural_programming', 'https://en.wikipedia.org/wiki/Imperative_programming', 'https://en.wikipedia.org/wiki/Functional_programming', 'https://en.wikipedia.org/wiki/Structured_programming', 'https://en.wikipedia.org/wiki/Reflective_programming', 'https://en.wikipedia.org/wiki/Software_design', 'https://en.wikipedia.org/wiki/Guid
# ...

# %%
import urllib.request #urllib3.error, urllib3.parse

url = 'http://www.liiofindia.org/in/cases/cen/INSC/1950/6.html'

response = urllib.request.urlopen()
webContent = response.read()

f = open('obo-t17800628-33.html', 'w')
f.write(webContent)
f.close
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-42-6bb583730ccf> in <module>
#       3 url = 'http://www.liiofindia.org/in/cases/cen/INSC/1950/6.html'
#       4
# ----> 5 response = urllib.request.urlopen(url)
#       6 webContent = response.read()
#       7
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
from bs4 import BeautifulSoup
import urllib3

http = urllib3.PoolManager()
s={'Accept': '*/*',
            'Accept-Language': 'en-US,en;q=0.5',
            'Host': 'liiofindia.org',
            'Referer': "http://www.liiofindia.org/in/cases/cen/INSC/1950/7.html",
            'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:28.0) Gecko/20100101 Firefox/28.0',
            'X-Requested-With': 'XMLHttpRequest'
            }
url = 'http://www.liiofindia.org/in/cases/cen/INSC/1950/6.html'
response = http.request('GET', url,headers=s)
soup = BeautifulSoup(response.data)
data = str(soup)
f = open('test.html', 'w')
f.write(data)
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
r=soup.strings

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html class="make-database">
# <head class="make-database">
# <title>SHETH MANEKLAL MANSUKHBHAI V. MESSRS. HORMUSJI JAMSHEDJI GINWALLAAND SONS [1950] INSC 6; AIR 1950 SC 1; 1950 SCR 75 (21 March 1950)</title>
# <meta content="text/html" http-equiv="Content-Type"/>
# <meta content="noindex, nofollow, noarchive" name="robots"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <link href="/make_database.css" rel="stylesheet" type="text/css"/>
# <link href="../../case.css" rel="stylesheet" type="text/css"/>
# </head>
# <body alink="#FF0000" bgcolor="#ffffff" class="make-database" link="#0044BB" marginheight="20" marginwidth="20" text="#000000" vlink="#660099">
# <p></p>
# <!--sino noindex-->
# <table border="0" cellpadding="2" cellspacing="2" class="make-database" width="100%">
# <tr class="make-database" valign="top">
# ...

# %%
f = open('test.html', 'w')
f.write(soup)
f.close
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0f3f5a393235> in <module>
#       1 f = open('test.html', 'w')
# ----> 2 f.write(soup)
#       3 f.close
#
# TypeError: write() argument must be str, not BeautifulSoup

# %%
urllib3.request.urlencode

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-846c1dbd158b> in <module>
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import requests
import lxml.html as lh
s={'Accept': '*/*',
            'Accept-Language': 'en-US,en;q=0.5',
            'Host': 'liiofindia.org',
            'Referer': "http://www.liiofindia.org/in/cases/cen/INSC/1950/7.html",
            'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:28.0) Gecko/20100101 Firefox/28.0',
            'X-Requested-With': 'XMLHttpRequest'
            }

url = 'http://www.liiofindia.org/in/cases/cen/INSC/1950/'

#Create a handle, page, to handle the contents of the website
page = requests.get(url,headers=s)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
for link in soup.findAll('a'):
    print link.get('href')

# %%
lh.
# Out:
# <Response [200]>

# %%
tr_elements = doc.xpath('//href')

# %%
tr_elements
# Out:
# []

# %%
for i in tr_elements:
    print(i.)
# Out:
# DHIYAN SINGH AND ANR V. JUGAL KISHORE AND ANR [1950] INSC 1; AIR 1952 SC 145; 1952 SCR 478
#  (22 February 1950)
# MESSRS. KHIMJI POONJA AND COMPANY V. SHRI BALDEV DAS C. PARIKH [1950] INSC 2; AIR 1950 SC 7; 1950 SCR 64
#  (14 March 1950)
# ABDULLA AHMED V. ANIMENDRA KISSEN MITTER [1950] INSC 3; AIR 1950 SC 15; 1950 SCR 30
#  (14 March 1950)
# BHAWANIPORE BANKING CORPORA-TION, LTD. V. GOURI SHANKAR SHARMA [1950] INSC 4; AIR 1950 SC 6; 1950 SCR 25
#  (14 March 1950)
# RAM KRISHNA RAMNATH AGARWALOF KAMPTEE V. SECRETARY, MUNICIPAL COMMITTEE, KAMPTEE & ORS [1950] INSC 5; AIR 1950 SC 11; 1950 SCR 15
#  (14 March 1950)
# SHETH MANEKLAL MANSUKHBHAI V. MESSRS. HORMUSJI JAMSHEDJI GINWALLAAND SONS [1950] INSC 6; AIR 1950 SC 1; 1950 SCR 75
#  (21 March 1950)
# NANALAL ZAVER & ANR V. BOMBAY LIFE ASSURANCE CO. LTD. & ORS [1950] INSC 7; AIR 1950 SC 172; 1950 SCR 391
#  (4 May 1950)
# ...

# %%
print(tr_elements[0].text_content())
# Out:
#
#
#
#
#
#
#
#
#         Home
#         | Databases
#         | WorldLII
#         | Search
#         | Feedback
#
#         Supreme Court of India
#
#
#
#   You are here:
#     LIIofIndia >>
#     Databases >>
#     Supreme Court of India >>
#     1950 >>
#     [1950] INSC 6
#
#
#
#   Database Search
#   | Name Search
#   | Recent Decisions
#   | Noteup
#   | LawCite
#   | Help
#
#
#
#
#     SHETH MANEKLAL MANSUKHBHAI V. MESSRS. HORMUSJI JAMSHEDJI GINWALLAAND SONS [1950] INSC 6; AIR 1950 SC 1; 1950 SCR 75 (21 March 1950)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 21/03/1950
#
#
# MAHAJAN, MEHR CHAND
#
# MAHAJAN, MEHR CHAND
# FAZAL ALI, SAIYID
# MUKHERJEA, B.K.
#
# CITATION:
#  1950 AIR    1		  [1950] INSC 6;  1950 SCR   75
#  CITATOR INFO :
#  RF	    1977 SC2425	 (5)
#
#
# ACT:
#     Transfer  of Property Act (IV of 1882), 8.	53-A--Agree-
# ment  to  lease evidenced by correspondence--Lessee  put  in
# possession--Acceptance
# of rent for several years--No  regis-
# ...

# %%
doc.get
# Out:
# <Element html at 0x204ab287540>

# %%
tr_elements[0].
# Out:
# <Element body at 0x204acb170e0>

# %%
import requests
url = 'http://www.liiofindia.org/in/cases/cen/INSC/1950/6.html'
# r = requests.get("http://www.liiofindia.org/in/cases/cen/INSC/1950/6.html")

# %%
page = requests.get(url,headers=s)

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n<html class="make-database">\n<head class="make-database">\n  <title>SHETH MANEKLAL MANSUKHBHAI V. MESSRS. HORMUSJI JAMSHEDJI GINWALLAAND SONS [1950] INSC 6; AIR 1950 SC 1; 1950 SCR 75 (21 March 1950)</title>\n  <meta http-equiv="Content-Type" content="text/html">\n  <meta name="robots" content="noindex, nofollow, noarchive">\n  <meta http-equiv="pragma" content="no-cache">\n  <meta http-equiv="cache-control" content="no-cache">\n  <link rel="stylesheet" type="text/css" href="/make_database.css"/>\n  <link rel="stylesheet" type="text/css" href="../../case.css"/>\n</head>\n<body class="make-database" bgcolor="#ffffff" text="#000000" link="#0044BB" alink="#FF0000" vlink="#660099" marginheight="20" marginwidth="20">\n<p></p>\n  <!--sino noindex-->\n  <table class="make-database" border="0" width="100%" cellspacing= "2" cellpadding="2">\n    <tr class="make-database" valign="top">\n      <td class="make-database" align="le
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
str(soup)
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n<html class="make-database">\n<head class="make-database">\n<title>SHETH MANEKLAL MANSUKHBHAI V. MESSRS. HORMUSJI JAMSHEDJI GINWALLAAND SONS [1950] INSC 6; AIR 1950 SC 1; 1950 SCR 75 (21 March 1950)</title>\n<meta content="text/html" http-equiv="Content-Type"/>\n<meta content="noindex, nofollow, noarchive" name="robots"/>\n<meta content="no-cache" http-equiv="pragma"/>\n<meta content="no-cache" http-equiv="cache-control"/>\n<link href="/make_database.css" rel="stylesheet" type="text/css"/>\n<link href="../../case.css" rel="stylesheet" type="text/css"/>\n</head>\n<body alink="#FF0000" bgcolor="#ffffff" class="make-database" link="#0044BB" marginheight="20" marginwidth="20" text="#000000" vlink="#660099">\n<p></p>\n<!--sino noindex-->\n<table border="0" cellpadding="2" cellspacing="2" class="make-database" width="100%">\n<tr class="make-database" valign="top">\n<td align="left" class="make-database" rowspan="2" width="10
# ...
