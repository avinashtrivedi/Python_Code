# %%
SouthAfricaCrimeStats_v2.csv

# %%
import pandas as pd
df = pd.read_csv('SouthAfricaCrimeStats_v2.csv')

# %%
df
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %%
df.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
df.columns
# Out:
# Index(['Province', 'Station', 'Category', '2005-2006', '2006-2007',
#        '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012',
#        '2012-2013', '2013-2014', '2014-2015', '2015-2016'],
#       dtype='object')

# %%
#1

# %%
df.head(10)
# Out:
#         Province            Station                           Category  \
# 0   Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1        Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2   Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3     Free State          Park Road  All theft not mentioned elsewhere
# 4        Gauteng   Pretoria Central  All theft not mentioned elsewhere
# 5     North West         Rustenburg  All theft not mentioned elsewhere
# 6  Kwazulu/Natal     Durban Central  All theft not mentioned elsewhere
# 7        Gauteng           Brooklyn  All theft not mentioned elsewhere
# 8        Gauteng           Booysens  All theft not mentioned elsewhere
# 9        Gauteng           Hillbrow  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# ...

# %%
#2

# %%
df['Province'].value_counts()
# Out:
# Eastern Cape     5292
# Kwazulu/Natal    5022
# Western Cape     4050
# Gauteng          3861
# Free State       2970
# Limpopo          2673
# Northern Cape    2457
# Mpumalanga       2322
# North West       2214
# Name: Province, dtype: int64

# %%
df.head()
# Out:
#        Province            Station                           Category  \
# 0  Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1       Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2  Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3    Free State          Park Road  All theft not mentioned elsewhere
# 4       Gauteng   Pretoria Central  All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       6093       4602       3761       3610       3267       3037
# 2       5341       6093       6316       6803       6035       5761
# 3       5108       4282       3834       3316       3101       3013
# 4       5099       4536       3309       2694       2616       2606
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# 0       5285       5937       5600       5335       5176
# ...

# %%
start = '2005' 
end = '2008'

year_range = start + '-' + end

# %%
t = df[(df['Province']=='Gauteng') & (df['Category']=='All theft not mentioned elsewhere')]

# %%
a=t.groupby(['Province']).sum()

# %%
a.sum(axis=1)
# Out:
# Province
# Gauteng    1273583
# dtype: int64

# %%
a
# Out:
#           2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# Province
# Gauteng      134063     128732     120918     120686     114196     113465
#
#           2011-2012  2012-2013  2013-2014  2014-2015  2015-2016
# Province
# Gauteng      111672     107285     110545     109422     102599

# %%
df
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %%
df[(df['2005-2006']==0) & (df['2006-2007']==0) & (df['Category']=='All theft not mentioned elsewhere')]
# Out:
#             Province           Station                           Category  \
# 28332   Eastern Cape               Ida  All theft not mentioned elsewhere
# 29356   Eastern Cape       Kwandengane  All theft not mentioned elsewhere
# 30327        Gauteng       Vaal Marina  All theft not mentioned elsewhere
# 30359        Limpopo          Rakgoadi  All theft not mentioned elsewhere
# 30462  Northern Cape         Augrabies  All theft not mentioned elsewhere
# 30504   Eastern Cape            Nemato  All theft not mentioned elsewhere
# 30515        Limpopo          Masemola  All theft not mentioned elsewhere
# 30560   Eastern Cape    St Francis Bay  All theft not mentioned elsewhere
# 30642        Limpopo        Mashashane  All theft not mentioned elsewhere
# 30648   Eastern Cape          Mlungisi  All theft not mentioned elsewhere
# 30652   Eastern Cape      Scenery Park  All theft not mentioned elsewhere
# 30657        Gauteng          Hekpoort  All theft not mentioned elsewhere
# ...

# %%
a.sum(axis=0)
# Out:
# 2005-2006    134063
# 2006-2007    128732
# 2007-2008    120918
# 2008-2009    120686
# 2009-2010    114196
# 2010-2011    113465
# 2011-2012    111672
# 2012-2013    107285
# 2013-2014    110545
# 2014-2015    109422
# 2015-2016    102599
# dtype: int64
