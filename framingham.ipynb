# %% [markdown]
# # Pre-Processing

# %%
# import the library
import pandas as pd

# %%
# load the training dataset
df_train  = pd.read_csv('Framingham_Training')

# display few rows
df_train
# Out:
#       Index  Sex  Age  Educ  Death
# 0         1    1   39     4      0
# 1         2    1   52     4      0
# 2         3    2   46     2      0
# 3         5    2   58     2      0
# 4         7    1   54     1      0
# ...     ...  ...  ...   ...    ...
# 7948  11327    1   40     3      0
# 7949  11329    1   52     3      0
# 7950  11330    2   39     3      0
# 7951  11331    2   46     3      0
# 7952  11332    2   50     3      0
#
# [7953 rows x 5 columns]

# %%
# Standardization of Age column using z-score method
df_train['Age'] = (df_train['Age'] - df_train['Age'].mean()) / df_train['Age'].std() 
df_train
# Out:
#       Index  Sex       Age  Educ  Death
# 0         1    1 -1.654082     4      0
# 1         2    1 -0.283734     4      0
# 2         3    2 -0.916202     2      0
# 3         5    2  0.348733     2      0
# 4         7    1 -0.072912     1      0
# ...     ...  ...       ...   ...    ...
# 7948  11327    1 -1.548670     3      0
# 7949  11329    1 -0.283734     3      0
# 7950  11330    2 -1.654082     3      0
# 7951  11331    2 -0.916202     3      0
# 7952  11332    2 -0.494557     3      0
#
# [7953 rows x 5 columns]

# %%
# Get Sex and Age column for clustering
X_train = df_train[['Sex','Age']].values
X_train
# Out:
# array([[ 1.        , -1.65408155],
#        [ 1.        , -0.28373444],
#        [ 2.        , -0.91620234],
#        ...,
#        [ 2.        , -1.65408155],
#        [ 2.        , -0.91620234],
#        [ 2.        , -0.49455708]])

# %% [markdown]
# # Q.1

# %%
# build K-Means model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 2, random_state = 42)
y_kmeans_train = kmeans.fit_predict(X_train) # fit and predict for X_train
y_kmeans_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Q.2

# %%
cluster1 = X_train[y_kmeans_train == 0] # get data for cluster 1
cluster2 = X_train[y_kmeans_train == 1] # get data for cluster 2

# %%
cluster1 # display cluster1 data for training data
# Out:
# array([[ 1.        , -1.65408155],
#        [ 1.        , -0.28373444],
#        [ 2.        , -0.91620234],
#        ...,
#        [ 2.        , -1.65408155],
#        [ 2.        , -0.91620234],
#        [ 2.        , -0.49455708]])

# %%
cluster2 # display cluster2 data for training data
# Out:
# array([[2.        , 0.34873345],
#        [2.        , 0.6649674 ],
#        [2.        , 1.29743529],
#        ...,
#        [1.        , 0.87579003],
#        [2.        , 0.55955608],
#        [2.        , 0.13791082]])

# %%
# summary statistics for cluster1
cluster1_train_summary = pd.DataFrame(cluster1 ,columns=['Sex','Age'])
cluster1_train_summary.describe()
# Out:
#                Sex          Age
# count  4336.000000  4336.000000
# mean      1.558118    -0.756019
# std       0.496668     0.552146
# min       1.000000    -2.391961
# 25%       1.000000    -1.127025
# 50%       2.000000    -0.705380
# 75%       2.000000    -0.283734
# max       2.000000     0.032500

# %%
# summary statistics for cluster2
cluster2_train_summary = pd.DataFrame(cluster2 ,columns=['Sex','Age'])
cluster2_train_summary.describe()
# Out:
#                Sex          Age
# count  3617.000000  3617.000000
# mean      1.579486     0.906303
# std       0.493710     0.571531
# min       1.000000     0.137911
# 25%       1.000000     0.454145
# 50%       2.000000     0.770379
# 75%       2.000000     1.297435
# max       2.000000     2.773194

# %% [markdown]
# -  Cluster1 consists of 4336 combinations of Sex and Age ,Although cluster2 consists of 3617 combinations of Sex and Age

# %% [markdown]
# # Q.3

# %%
# load test data
df_test  = pd.read_csv('Framingham_Test')
df_test
# Out:
#       Index  Sex  Age  Educ  Death
# 0         4    2   52     2      0
# 1         6    1   48     1      0
# 2        10    2   46     3      0
# 3        14    2   49     2      0
# 4        16    2   63     1      0
# ...     ...  ...  ...   ...    ...
# 2252  11307    2   56     1      0
# 2253  11313    1   68     1      1
# 2254  11323    2   50     1      1
# 2255  11326    2   58     2      0
# 2256  11328    1   46     3      0
#
# [2257 rows x 5 columns]

# %%
# Standardization of Age column using z-score method
df_test['Age'] = (df_test['Age'] - df_test['Age'].mean()) / df_test['Age'].std() 
df_test
# Out:
#       Index  Sex       Age  Educ  Death
# 0         4    2 -0.273782     2      0
# 1         6    1 -0.686008     1      0
# 2        10    2 -0.892121     3      0
# 3        14    2 -0.582951     2      0
# 4        16    2  0.859838     1      0
# ...     ...  ...       ...   ...    ...
# 2252  11307    2  0.138444     1      0
# 2253  11313    1  1.375121     1      1
# 2254  11323    2 -0.479895     1      1
# 2255  11326    2  0.344556     2      0
# 2256  11328    1 -0.892121     3      0
#
# [2257 rows x 5 columns]

# %%
# Get Sex and Age column for clustering
X_test = df_test[['Sex','Age']].values
X_test
# Out:
# array([[ 2.        , -0.27378213],
#        [ 1.        , -0.68600779],
#        [ 2.        , -0.89212062],
#        ...,
#        [ 2.        , -0.47989496],
#        [ 2.        ,  0.34455636],
#        [ 1.        , -0.89212062]])

# %%
y_kmeans_test = kmeans.predict(X_test) # predict using X_test
y_kmeans_test
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %% [markdown]
# # Q.4

# %%
# get data for cluster 1
cluster1 = X_test[y_kmeans_test == 0]

# get data for cluster 2
cluster2 = X_test[y_kmeans_test == 1]

# %%
cluster1 # display cluster1 for test data
# Out:
# array([[ 2.        , -0.27378213],
#        [ 1.        , -0.68600779],
#        [ 2.        , -0.89212062],
#        ...,
#        [ 1.        , -0.0676693 ],
#        [ 2.        , -0.47989496],
#        [ 1.        , -0.89212062]])

# %%
cluster2 # display cluster2 for test data
# Out:
# array([[2.        , 0.85983844],
#        [2.        , 0.13844353],
#        [2.        , 0.96289485],
#        ...,
#        [2.        , 0.13844353],
#        [1.        , 1.37512051],
#        [2.        , 0.34455636]])

# %%
# summary statistics for cluster1
cluster1_test_summary = pd.DataFrame(cluster1 ,columns=['Sex','Age'])
cluster1_test_summary.describe()
# Out:
#                Sex          Age
# count  1245.000000  1245.000000
# mean      1.559036    -0.751484
# std       0.496702     0.537188
# min       1.000000    -2.231854
# 25%       1.000000    -1.098233
# 50%       2.000000    -0.686008
# 75%       2.000000    -0.273782
# max       2.000000     0.035387

# %%
# summary statistics for cluster2
cluster2_test_summary = pd.DataFrame(cluster2 ,columns=['Sex','Age'])
cluster2_test_summary.describe()
# Out:
#                Sex          Age
# count  1012.000000  1012.000000
# mean      1.591897     0.924503
# std       0.491725     0.570430
# min       1.000000     0.138444
# 25%       1.000000     0.447613
# 50%       2.000000     0.859838
# 75%       2.000000     1.272064
# max       2.000000     2.714854

# %% [markdown]
# # Are your clusters validated?
#
# - Yes, because we have predicted the clustering of test data using the same K-Means Model that was earlier trained using Training set.
