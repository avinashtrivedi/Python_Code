# %%
import pandas as pd

# %%
data = pd.read_csv('gapminder_all.csv')

# %%
data
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
data.describe().T
# Out:
#                 count          mean           std            min  \
# gdpPercap_1952  142.0  3.725276e+03  9.321065e+03     298.846212
# gdpPercap_1957  142.0  4.299408e+03  9.869662e+03     335.997115
# gdpPercap_1962  142.0  4.725812e+03  8.667363e+03     355.203227
# gdpPercap_1967  142.0  5.483653e+03  8.095315e+03     349.000000
# gdpPercap_1972  142.0  6.770083e+03  1.061438e+04     357.000000
# gdpPercap_1977  142.0  7.313166e+03  8.362489e+03     371.000000
# gdpPercap_1982  142.0  7.518902e+03  7.733845e+03     424.000000
# gdpPercap_1987  142.0  7.900920e+03  8.288281e+03     385.000000
# gdpPercap_1992  142.0  8.158609e+03  9.031846e+03     347.000000
# gdpPercap_1997  142.0  9.090175e+03  1.017149e+04     312.188423
# gdpPercap_2002  142.0  9.917848e+03  1.115411e+04     241.165876
# gdpPercap_2007  142.0  1.168007e+04  1.285994e+04     277.551859
# lifeExp_1952    142.0  4.905762e+01  1.222596e+01      28.801000
# ...

# %%
data['country']
# Out:
# 0             Algeria
# 1              Angola
# 2               Benin
# 3            Botswana
# 4        Burkina Faso
#             ...
# 137       Switzerland
# 138            Turkey
# 139    United Kingdom
# 140         Australia
# 141       New Zealand
# Name: country, Length: 142, dtype: object

# %%
data.indexc
# Out:
#                continent country  gdpPercap_1952  gdpPercap_1957  \
# country
# Algeria              NaN     NaN             NaN             NaN
# Angola               NaN     NaN             NaN             NaN
# Benin                NaN     NaN             NaN             NaN
# Botswana             NaN     NaN             NaN             NaN
# Burkina Faso         NaN     NaN             NaN             NaN
# ...                  ...     ...             ...             ...
# Switzerland          NaN     NaN             NaN             NaN
# Turkey               NaN     NaN             NaN             NaN
# United Kingdom       NaN     NaN             NaN             NaN
# Australia            NaN     NaN             NaN             NaN
# New Zealand          NaN     NaN             NaN             NaN
#
#                 gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# country
# Algeria                    NaN             NaN             NaN
# ...

# %%
index_col = data['country']

# %%
index_col.describe()
# Out:
# count        142
# unique       142
# top       Israel
# freq           1
# Name: country, dtype: object

# %%
import numpy as np

# %%
x = np.linspace(-5,5)

# %%
x
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
y = np.arctan(np.arctan(x))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlim([-5,5])
plt.ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %%
x = np.linspace(-2,3)
y = (x+2)*(x+1)*(x-1)*(x-2)*(x-3)

# %%
plt.plot(x,y)
plt.xlim([-2,3])
plt.ylim([-15,15])
# Out:
# (-15.0, 15.0)

# %%
import math

def func_e(x, n):
    e_approx = 0
    for i in range(n):
        e_approx += x**i/math.factorial(i)
    
    return e_approx

# %%
func_e(x, n)

# %%
plt.plot(0,1)
