# %%
import pandas as pd

# %%
# df = pd.read_csv('https://philchodrow.github.io/PIC16A/datasets/gapminder.csv')

# %%
df = pd.read_csv('gapminder.csv')

# %%
df.groupby(["country"])

# %%
df[df['continent']=='Asia']

# %%
x = df[df['continent']=='Asia'][['year','lifeExp']]

# %%
import matplotlib.pyplot as plt

# %%
x
# Out:
#       year  lifeExp
# 0     1952   28.801
# 1     1957   30.332
# 2     1962   31.997
# 3     1967   34.020
# 4     1972   36.088
# ...    ...      ...
# 1675  1987   52.922
# 1676  1992   55.599
# 1677  1997   58.020
# 1678  2002   60.308
# 1679  2007   62.698
#
# [396 rows x 2 columns]

# %%
plt.plot(k['year'],k['lifeExp'])

# %%
x = df[df['continent']=='Europe'][['year','lifeExp']]
plt.plot(x['year'],x['lifeExp'],color='yellow')

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df = df[['country','continent','year','lifeExp']]

# %%
df.groupby(['continent'])[['year','lifeExp']].apply(lambda x: dict(x))
# Out:
# continent
# Africa      {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Americas    {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Asia        {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Europe      {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Oceania     {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# dtype: object

# %%
x
# Out:
# continent
# Africa      {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Americas    {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Asia        {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Europe      {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# Oceania     {'year': [1952, 1957, 1962, 1967, 1972, 1977, ...
# dtype: object

# %%
x['Africa']['year']
# Out:
# 60      1952
# 61      1957
# 62      1962
# 63      1967
# 64      1972
# 65      1977
# 66      1982
# 67      1987
# 68      1992
# 69      1997
# 70      2002
# 71      2007
# 1092    1952
# 1093    1957
# 1094    1962
# 1095    1967
# 1096    1972
# 1097    1977
# 1098    1982
# 1099    1987
# 1100    1992
# 1101    1997
# 1102    2002
# 1103    2007
#         1952
#         1957
#         1962
#         1967
#         1972
#         1977
#         1982
#         1987
#         1992
#         1997
#         2002
#         2007
#         1952
#         1957
#         1962
#         1967
#         1972
#         1977
#         1982
#         1987
#         1992
#         1997
#         2002
#         2007
#         1952
#         1957
#         1962
#         1967
#         1972
#         1977
#         1982
#         1987
#         1992
#         1997
#         2002
#         2007
#         1952
#         1957
#         1962
#         1967
#         1972
#         1977
# ...

# %%
df
# Out:
#      continent  year  lifeExp
# 0         Asia  1952   28.801
# 1         Asia  1957   30.332
# 2         Asia  1962   31.997
# 3         Asia  1967   34.020
# 4         Asia  1972   36.088
# ...        ...   ...      ...
# 1699    Africa  1987   62.351
# 1700    Africa  1992   60.377
# 1701    Africa  1997   46.809
# 1702    Africa  2002   39.989
# 1703    Africa  2007   43.487
#
# [1704 rows x 3 columns]

# %%
df.groupby(['Type']).apply(lambda grp: grp.groupby('Name')['Type'].count().to_dict()).to_dict()

# %%
df
# Out:
#      continent  year  lifeExp
# 0         Asia  1952   28.801
# 1         Asia  1957   30.332
# 2         Asia  1962   31.997
# 3         Asia  1967   34.020
# 4         Asia  1972   36.088
# ...        ...   ...      ...
# 1699    Africa  1987   62.351
# 1700    Africa  1992   60.377
# 1701    Africa  1997   46.809
# 1702    Africa  2002   39.989
# 1703    Africa  2007   43.487
#
# [1704 rows x 3 columns]

# %%
df.set_index('country').to_dict()
# Out:
# {'continent': {'Afghanistan': 'Asia',
#   'Albania': 'Europe',
#   'Algeria': 'Africa',
#   'Angola': 'Africa',
#   'Argentina': 'Americas',
#   'Australia': 'Oceania',
#   'Austria': 'Europe',
#   'Bahrain': 'Asia',
#   'Bangladesh': 'Asia',
#   'Belgium': 'Europe',
#   'Benin': 'Africa',
#   'Bolivia': 'Americas',
#   'Bosnia and Herzegovina': 'Europe',
#   'Botswana': 'Africa',
#   'Brazil': 'Americas',
#   'Bulgaria': 'Europe',
#   'Burkina Faso': 'Africa',
#   'Burundi': 'Africa',
#   'Cambodia': 'Asia',
#   'Cameroon': 'Africa',
#   'Canada': 'Americas',
#   'Central African Republic': 'Africa',
#   'Chad': 'Africa',
#   'Chile': 'Americas',
#   'China': 'Asia',
#   'Colombia': 'Americas',
#   'Comoros': 'Africa',
#   'Congo, Dem. Rep.': 'Africa',
#   'Congo, Rep.': 'Africa',
#   'Costa Rica': 'Americas',
#   "Cote d'Ivoire": 'Africa',
#   'Croatia': 'Europe',
#   'Cuba': 'Americas',
#   'Czech Republic': 'Europe',
#   'Denmark': 'Europe',
#   'Djibouti': 'Africa',
# ...

# %%
df = df[['country','continent','year','lifeExp']]

# %%
df = df[['continent','year','lifeExp']]

# %%
df
# Out:
#           country continent  year  lifeExp
# 0     Afghanistan      Asia  1952   28.801
# 1     Afghanistan      Asia  1957   30.332
# 2     Afghanistan      Asia  1962   31.997
# 3     Afghanistan      Asia  1967   34.020
# 4     Afghanistan      Asia  1972   36.088
# ...           ...       ...   ...      ...
# 1699     Zimbabwe    Africa  1987   62.351
# 1700     Zimbabwe    Africa  1992   60.377
# 1701     Zimbabwe    Africa  1997   46.809
# 1702     Zimbabwe    Africa  2002   39.989
# 1703     Zimbabwe    Africa  2007   43.487
#
# [1704 rows x 4 columns]

# %%
df
# Out:
#      continent  year  lifeExp
# 0         Asia  1952   28.801
# 1         Asia  1957   30.332
# 2         Asia  1962   31.997
# 3         Asia  1967   34.020
# 4         Asia  1972   36.088
# ...        ...   ...      ...
# 1699    Africa  1987   62.351
# 1700    Africa  1992   60.377
# 1701    Africa  1997   46.809
# 1702    Africa  2002   39.989
# 1703    Africa  2007   43.487
#
# [1704 rows x 3 columns]

# %%
d = {cnt: {'year': val['year'].tolist(),'lfexp': val['lifeExp'].tolist()}  for cnt,val in df.groupby("continent")}

# %%
df.groupby("country").apply(lambda x : {x['continent'] : {'year': x['year'],'lfexp': x['lifeExp']}})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#
# <ipython-input-133-0da139cbd0fc> in <lambda>(x)
# ...

# %%
s = df.groupby("continent").apply(lambda x :{'year': x['year'].tolist(),'lifeExp': x['lifeExp'].tolist()}).to_dict()

# %%
s.keys()
# Out:
# dict_keys(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'])

# %%
s.keys()
# Out:
# dict_keys(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'])

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
plt.plot(s['Oceania']['year'],s['Oceania']['lifeExp'])

# %%
d.keys()
# Out:
# dict_keys(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'])

# %%
a = lambda x, y: (x+y, x-y)

# %%
a(2,3)
# Out:
# (5, -1)

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
df
# Out:
#      year  lifeExp   cntnt
# 0    1952   43.077  Africa
# 1    1957   45.685  Africa
# 2    1962   48.303  Africa
# 3    1967   51.407  Africa
# 4    1972   54.518  Africa
# ..    ...      ...     ...
# 391  1987   52.922    Asia
# 392  1992   55.599    Asia
# 393  1997   58.020    Asia
# 394  2002   60.308    Asia
# 395  2007   62.698    Asia
#
# [1020 rows x 3 columns]

# %%
pd.pivot_table(df.reset_index(),
               index='index', columns='identifier', values='value'
               )

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
df.groupby("continent").apply(lambda x :{'year': x['year'].tolist(),'lifeExp': x['lifeExp'].tolist()}).to_dict()
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
d = pd.DataFrame(s)

# %%
d.index
# Out:
# Index(['year', 'lifeExp'], dtype='object')

# %%
d.loc['year']
# Out:
# Africa      [1952, 1957, 1962, 1967, 1972, 1977, 1982, 198...
# Americas    [1952, 1957, 1962, 1967, 1972, 1977, 1982, 198...
# Asia        [1952, 1957, 1962, 1967, 1972, 1977, 1982, 198...
# Europe      [1952, 1957, 1962, 1967, 1972, 1977, 1982, 198...
# Oceania     [1952, 1957, 1962, 1967, 1972, 1977, 1982, 198...
# Name: year, dtype: object

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
import numpy as np
x = np.arange(0.0, 2.0, 0.01)
y = 1 + np.sin(2 * np.pi * x)

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5)
ax1.plot(x, y, color="orange")

# %%
plt.plot(s['Asia'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-236-fc9d8d6c052c> in <module>
# ----> 1 plt.plot(s['Asia'])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1747         return lines
# ...

# %%
d= pd.DataFrame(s['Asia'])

# %%
plt.plot(d['year'],d['lifeExp'])

# %%
s
# Out:
# {'Africa': {'year': [1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    1952,
#    1957,
#    1962,
#    1967,
#    1972,
# ...

# %%
s = df.groupby("continent").apply(lambda x :{'year': x['year'].tolist(),'lifeExp': x['lifeExp'].tolist()}).to_dict()

# %%
df.groupby("continent").apply(lambda x :{'year': x['year'].tolist(),'lifeExp': x['lifeExp'].tolist()}).to_dict()

# %%
s.keys()
# Out:
# dict_keys(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'])

# %%
s['Asia'].keys()
# Out:
# dict_keys(['year', 'lifeExp'])

# %%
s['Asia']

# %%
import seaborn as sns
sns.palettes(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-303e22180f11> in <module>
#       1 import seaborn as sns
# ----> 2 sns.palettes(s)
#
# TypeError: 'module' object is not callable

# %%
k=pd.DataFrame(s['Asia'])

# %%
plt.plot()
# Out:
# <AxesSubplot:>

# %%
df['cntnt'] = 'Asia'

# %%
df
# Out:
#      year  lifeExp cntnt
# 0    1952   28.801  Asia
# 1    1957   30.332  Asia
# 2    1962   31.997  Asia
# 3    1967   34.020  Asia
# 4    1972   36.088  Asia
# ..    ...      ...   ...
# 391  1987   52.922  Asia
# 392  1992   55.599  Asia
# 393  1997   58.020  Asia
# 394  2002   60.308  Asia
# 395  2007   62.698  Asia
#
# [396 rows x 3 columns]

# %%
df1 = pd.DataFrame(s['Africa'])
df1['cntnt'] = 'Africa'

df2 = pd.DataFrame(s['Asia'])
df2['cntnt'] = 'Asia'

# %%
df = df1.append(df2)

# %%
df
# Out:
#      year  lifeExp   cntnt
# 0    1952   43.077  Africa
# 1    1957   45.685  Africa
# 2    1962   48.303  Africa
# 3    1967   51.407  Africa
# 4    1972   54.518  Africa
# ..    ...      ...     ...
# 391  1987   52.922    Asia
# 392  1992   55.599    Asia
# 393  1997   58.020    Asia
# 394  2002   60.308    Asia
# 395  2007   62.698    Asia
#
# [1020 rows x 3 columns]

# %%
plt.subplots(1, 2,sharex='col')
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
lambda x :

# %%
# attend = sns.load_dataset("attention").query("subject <= 5")
g = sns.FacetGrid(df, col="cntnt", col_wrap=3, height=2, ylim=(0, 80))
g.map(sns.lineplot, "year", "lifeExp")

# %%
sns.

# %%
attend = sns.load_dataset("attention").query("subject <= 5")
g = sns.FacetGrid(attend, col="subject", col_wrap=5, height=2, ylim=(0, 10))
g.map(sns.pointplot, "solutions", "score")
# Out:
# C:\Users\avitr\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
attend
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 20          20        1   divided          2    4.0
# 21          21        2   divided          2    4.0
# 22          22        3   divided          2    5.0
# 23          23        4   divided          2    7.0
# 24          24        5   divided          2    5.0
# 40          40        1   divided          3    7.0
# 41          41        2   divided          3    5.0
# 42          42        3   divided          3    6.0
# 43          43        4   divided          3    5.0
# 44          44        5   divided          3    8.0

# %%
df
# Out:
#      year  lifeExp   cntnt
# 0    1952   43.077  Africa
# 1    1957   45.685  Africa
# 2    1962   48.303  Africa
# 3    1967   51.407  Africa
# 4    1972   54.518  Africa
# ..    ...      ...     ...
# 391  1987   52.922    Asia
# 392  1992   55.599    Asia
# 393  1997   58.020    Asia
# 394  2002   60.308    Asia
# 395  2007   62.698    Asia
#
# [1020 rows x 3 columns]

# %%
df
# Out:
#      year  lifeExp   cntnt
# 0    1952   43.077  Africa
# 1    1957   45.685  Africa
# 2    1962   48.303  Africa
# 3    1967   51.407  Africa
# 4    1972   54.518  Africa
# ..    ...      ...     ...
# 391  1987   52.922    Asia
# 392  1992   55.599    Asia
# 393  1997   58.020    Asia
# 394  2002   60.308    Asia
# 395  2007   62.698    Asia
#
# [1020 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
# ax1.plot(x, y, color="orange")
d={'Asia':ax1,
   'Africa':ax2
}
df.groupby("continent").apply(lambda x: ax1.plot(x['year'],x['lifeExp']))
# Out:
# continent
# Africa      [Line2D(_line0)]
# Americas    [Line2D(_line1)]
# Asia        [Line2D(_line2)]
# Europe      [Line2D(_line3)]
# Oceania     [Line2D(_line4)]
# dtype: object

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
# set_title
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1, 5,figsize=(20,3),sharey=True)
ax1.plot(range(10),range(10)).
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-435-2e0c9320be60> in <module>
#       1 # set_title
#       2 fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1, 5,figsize=(20,3),sharey=True)
# ----> 3 ax1.plot(range(10),range(10)).set_title('uu')
#
# AttributeError: 'list' object has no attribute 'set_title'

# %%
fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1, 5,figsize=(20,3),sharey=True)
# ax1.plot(x, y, color="orange")
d={'Asia':ax1,
   'Africa':ax2,
   'Europe':ax3,
   'Americas':ax4,
   'Oceania':ax5
  }

c={'Asia':'blue',
   'Africa':'green',
   'Europe':'yellow',
   'Americas':'orange',
   'Oceania':'deeppink'
  }


# df.groupby("country").apply(lambda x: plt.plot(x['year'],x['lifeExp']))
df.groupby("country").apply(lambda x: (d[list(set(x['continent']))[0]].plot(x['year'],
                                                                           x['lifeExp'],
                                                                           color=c[list(set(x['continent']))[0]] 
          
                                                                          ),d[list(set(x['continent']))[0]].set_title(list(set(x['continent']))[0])))
ax.set_yticks(list(range(30,91,10)))
plt.show()
# df.groupby("country").apply(lambda x: x['continent'])  set_title
# lambda x:d[list(set(x['continent']))[0]].set_title(list(set(x['continent']))[0])

# %%
a={1}

# %%
a=[1,1,1,1]

# %%
df.groupby("country").apply(lambda x: x['continent'].to_dict())
# Out:
# country
# Afghanistan           {0: 'Asia', 1: 'Asia', 2: 'Asia', 3: 'Asia', 4...
# Albania               {12: 'Europe', 13: 'Europe', 14: 'Europe', 15:...
# Algeria               {24: 'Africa', 25: 'Africa', 26: 'Africa', 27:...
# Angola                {36: 'Africa', 37: 'Africa', 38: 'Africa', 39:...
# Argentina             {48: 'Americas', 49: 'Americas', 50: 'Americas...
#                                             ...
# Vietnam               {1644: 'Asia', 1645: 'Asia', 1646: 'Asia', 164...
# West Bank and Gaza    {1656: 'Asia', 1657: 'Asia', 1658: 'Asia', 165...
# Yemen, Rep.           {1668: 'Asia', 1669: 'Asia', 1670: 'Asia', 167...
# Zambia                {1680: 'Africa', 1681: 'Africa', 1682: 'Africa...
# Zimbabwe              {1692: 'Africa', 1693: 'Africa', 1694: 'Africa...
# Length: 142, dtype: object

# %%
df.groupby("country").apply(lambda x: d['Asia'].plot(x['year'],x['lifeExp']))
# Out:
# country
# Afghanistan           [Line2D(_line284)]
# Albania               [Line2D(_line285)]
# Algeria               [Line2D(_line286)]
# Angola                [Line2D(_line287)]
# Argentina             [Line2D(_line288)]
#                              ...
# Vietnam               [Line2D(_line421)]
# West Bank and Gaza    [Line2D(_line422)]
# Yemen, Rep.           [Line2D(_line423)]
# Zambia                [Line2D(_line424)]
# Zimbabwe              [Line2D(_line425)]
# Length: 142, dtype: object

# %%
df.groupby("continent").apply(lambda x: plt.plot(x['year'],x['lifeExp'],))
# Out:
# continent
# Africa      [Line2D(_line0)]
# Americas    [Line2D(_line1)]
# Asia        [Line2D(_line2)]
# Europe      [Line2D(_line3)]
# Oceania     [Line2D(_line4)]
# dtype: object

# %%
list(s)[0]

# %%
a = lambda x, y: (x+y, x-y)

# %%
a(2,3)
# Out:
# (5, -1)
