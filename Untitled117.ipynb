# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('gapminder.csv')

# %%
df = df[['continent','year','gdpPercap']]

# %%
a = df.groupby(['country']).apply(lambda x:x)

# %%
a
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
d=a[a['continent']=='Asia']

# %%
d[d['year']==1952]
# Out:
#      continent  year      gdpPercap
# 0         Asia  1952     779.445314
# 84        Asia  1952    9867.084765
# 96        Asia  1952     684.244172
# 216       Asia  1952     368.469286
# 288       Asia  1952     400.448611
# 660       Asia  1952    3054.421209
# 696       Asia  1952     546.565749
# 708       Asia  1952     749.681655
# 720       Asia  1952    3035.326002
# 732       Asia  1952    4129.766056
# 756       Asia  1952    4086.522128
# 792       Asia  1952    3216.956347
# 804       Asia  1952    1546.907807
# 828       Asia  1952    1088.277758
# 840       Asia  1952    1030.592226
# 852       Asia  1952  108382.352900
# 864       Asia  1952    4834.804067
# 936       Asia  1952    1831.132894
# 996       Asia  1952     786.566857
# 1044      Asia  1952     331.000000
# 1068      Asia  1952     545.865723
# 1152      Asia  1952    1828.230307
# 1164      Asia  1952     684.597144
# 1212      Asia  1952    1272.880995
# 1308      Asia  1952    6459.554823
# ...

# %%
fgrid = sns.relplot(data=a,
                   x='year',
                   y='gdpPercap',
                   col='continent',
                   kind='line',
                   col_wrap=3,
                   size="country",
                   legend=False
                   )
# fgrid.fig.autofmt_xdate()
# fgrid.
# fgrid.set(ylim=(0, 10000))
# fgrid.map(sns.lineplot, "year", "gdpPercap")
# for ax in fgrid.axes.flatten():
#     ax.semilogx()

# %%
# import matplotlib.pyplot as plt
# g = sns.FacetGrid(a, col="continent",hue="gdpPercap", col_wrap=5)
# g.map(sns.lineplot, "year","gdpPercap", "continent")
# plt.show()
# Out:
# Exception ignored in: <function WeakMethod.__new__.<locals>._cb at 0x0000020668EF1670>
# Traceback (most recent call last):
#   File "C:\Users\avitr\anaconda3\lib\weakref.py", line 54, in _cb
#     self = self_wr()
# KeyboardInterrupt:

# %%
sns.relplot(data=a,
                   x='year',
                   y='gdpPercap',
                   col='continent',
                   estimator=None,
                   kind='line',
                   col_wrap=3
                  )

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            kind="line", data=dots);

# %%
a.reset_index(drop=True,inplace=True)

# %%
a
# Out:
#      continent  year   gdpPercap
# 0         Asia  1952  779.445314
# 1         Asia  1957  820.853030
# 2         Asia  1962  853.100710
# 3         Asia  1967  836.197138
# 4         Asia  1972  739.981106
# ...        ...   ...         ...
# 1699    Africa  1987  706.157306
# 1700    Africa  1992  693.420786
# 1701    Africa  1997  792.449960
# 1702    Africa  2002  672.038623
# 1703    Africa  2007  469.709298
#
# [1704 rows x 3 columns]
